# %%
#import json
import pickle
#import CwnGraph, DistilTag, CwnSenseTagger
#from DistilTag import DistilTag  
#from CwnSenseTagger import senseTag

# %% [markdown]
# ## 1. Load Data

# %%
with open("kh_tagged.pkl", "rb") as f:
    kh_tagged = pickle.load(f)
    
with open("kh_tagged_sense.pkl", "rb") as f:
    kh_tagged_sense = pickle.load(f)
    
with open("tp_tagged.pkl", "rb") as f:
    tp_tagged = pickle.load(f)
    
with open("tp_tagged_sense.pkl", "rb") as f:
    tp_tagged_sense = pickle.load(f)

# %% [markdown]
# ## 2. Make Frequency Lists

# %%
# making frequency tables
def freq_tables(sense_tagged_data):
    word_freq = {}
    pos_freq = {}
    sense_freq = {}

    for post in sense_tagged_data:
        for sent in post:
            for form, pos, sense_id, sense_def in sent:

                if form not in word_freq:
                    word_freq[form] = 1
                else:
                    word_freq[form] += 1

                word_pos = f"{form}_{pos}"
                if word_pos not in pos_freq:
                    pos_freq[word_pos] = 1
                else:
                    pos_freq[word_pos] += 1

                word_sense = f"{form}_{sense_id}_{sense_def}"
                if word_sense not in sense_freq:
                    sense_freq[word_sense] = 1
                else:
                    sense_freq[word_sense] += 1
        
    return word_freq, pos_freq, sense_freq

# %% [markdown]
# ### 2.1. 高雄板詞頻表、詞類頻表、詞義頻表

# %% [markdown]
# #### 2.1.1 高雄板詞頻表

# %%
# sorting word frequency tables
kh_tables = freq_tables(kh_tagged_sense)
kh_tables_word = list(kh_tables[0].items())
sorted(kh_tables_word, reverse=True, key=lambda x: x[1])[0:99]
# Out:
# [('：', 1296),
#  ('，', 802),
#  ('判決', 424),
#  ('。', 408),
#  ('．', 282),
#  ('原文', 259),
#  ('的', 249),
#  ('不', 237),
#  ('依', 210),
#  ('水桶', 165),
#  ('、', 158),
#  ('或', 153),
#  ('屬', 152),
#  ('處', 150),
#  ('］', 146),
#  ('［', 144),
#  ('是', 141),
#  ('之', 140),
#  ('一', 131),
#  ('有', 127),
#  ('故', 121),
#  ('（', 113),
#  ('６１', 111),
#  ('）', 110),
#  ('日', 107),
#  ('新聞', 100),
#  ('高雄', 95),
#  ('７', 91),
#  ('針對', 89),
#  ('規定', 88),
#  ('就', 85),
#  ('者', 80),
#  ('了', 78),
#  ('經', 73),
#  ('板友', 72),
#  ('內容', 71),
#  ('文', 70),
#  ('在', 68),
#  ('？', 62),
#  ('已', 62),
#  ('引起', 62),
#  ('爭端', 62),
#  ('請', 59),
#  ('影射', 59),
#  ('上', 57),
#  ('以', 54),
#  ('特定', 54),
#  ('不當', 54),
#  ('為', 53),
#  ('徵求', 52),
#  ('族群', 52),
#  ('無', 51),
#  ('人', 50),
#  ('會', 47),
#  ('這', 47),
#  ('並', 47),
#  ('歧視', 47),
#  ('／／ｉ', 46),
#  ('ｉｍｇｕｒ', 46),
#  ('我', 45),
#  ('但', 43),
#  ('次', 43),
#  ('都', 43),
#  ('交換', 43),
#  ('查', 42),
#  ('退文', 41),
#  ('被', 40),
#  ('內文', 40),
#  ('也', 39),
#  ('內', 39),
#  ('文章', 39),
#  ('個', 39),
#  ('警告', 39),
#  ('ｈｔｔｐｓ', 38),
#  ('與', 37),
#  ('刪', 37),
#  ('禁止', 36),
#  ('應', 36),
#  ('同', 36),
#  ('可以', 35),
#  ('於', 35),
#  ('２', 34),
#  ('再', 34),
#  ('年', 34),
#  ('篇', 34),
#  ('檢舉', 33),
#  ('違反', 33),
#  ('交易文', 33),
#  ('可', 32),
#  ('好', 31),
#  ('很', 31),
#  ('要', 31),
#  ('不足', 31),
#  ('階', 30),
#  ('多', 29),
#  ('相關', 29),
#  ('還', 29),
#  ('程度', 29),
#  ('１', 28)]

# %% [markdown]
# #### 2.1.2 高雄板詞類頻表

# %%
# sorting pos frequency tables
kh_tables_pos = list(kh_tables[1].items())
sorted(kh_tables_pos, reverse=True, key=lambda x: x[1])[0:99]
# Out:
# [('：_COLONCATEGORY', 1296),
#  ('，_COMMACATEGORY', 802),
#  ('。_PERIODCATEGORY', 408),
#  ('判決_VE', 408),
#  ('．_PERIODCATEGORY', 282),
#  ('原文_Na', 259),
#  ('不_D', 237),
#  ('的_DE', 233),
#  ('依_P', 210),
#  ('水桶_Na', 165),
#  ('、_PAUSECATEGORY', 158),
#  ('或_Caa', 153),
#  ('屬_VG', 152),
#  ('］_PARENTHESISCATEGORY', 146),
#  ('［_PARENTHESISCATEGORY', 144),
#  ('是_SHI', 141),
#  ('一_Neu', 129),
#  ('有_V_2', 126),
#  ('故_Cbb', 118),
#  ('之_DE', 116),
#  ('（_PARENTHESISCATEGORY', 113),
#  ('６１_Neu', 111),
#  ('）_PARENTHESISCATEGORY', 110),
#  ('日_Nf', 106),
#  ('新聞_Na', 100),
#  ('高雄_Nc', 94),
#  ('針對_P', 89),
#  ('處_Nf', 83),
#  ('就_D', 81),
#  ('者_Na', 80),
#  ('經_P', 73),
#  ('板友_Na', 72),
#  ('內容_Na', 71),
#  ('文_Na', 70),
#  ('７_Neu', 67),
#  ('處_Nc', 64),
#  ('？_QUESTIONCATEGORY', 62),
#  ('已_D', 62),
#  ('規定_Na', 62),
#  ('引起_VC', 62),
#  ('爭端_Na', 62),
#  ('了_Di', 59),
#  ('請_VF', 59),
#  ('在_P', 57),
#  ('影射_Na', 55),
#  ('特定_A', 54),
#  ('不當_VH', 54),
#  ('族群_Na', 52),
#  ('人_Na', 50),
#  ('以_P', 50),
#  ('徵求_VC', 47),
#  ('歧視_Nv', 47),
#  ('／／ｉ_FW', 46),
#  ('ｉｍｇｕｒ_FW', 46),
#  ('會_D', 46),
#  ('這_Nep', 46),
#  ('我_Nh', 45),
#  ('但_Cbb', 43),
#  ('都_D', 43),
#  ('為_VG', 43),
#  ('無_VJ', 43),
#  ('次_Nf', 42),
#  ('查_VE', 42),
#  ('交換_VC', 41),
#  ('被_P', 40),
#  ('內文_Na', 40),
#  ('也_D', 39),
#  ('文章_Na', 39),
#  ('個_Nf', 39),
#  ('刪_VC', 37),
#  ('禁止_VE', 36),
#  ('應_D', 36),
#  ('於_P', 35),
#  ('可以_D', 34),
#  ('２_Neu', 34),
#  ('再_D', 34),
#  ('篇_Nf', 34),
#  ('並_Cbb', 34),
#  ('違反_VJ', 33),
#  ('交易文_Na', 33),
#  ('警告_VE', 33),
#  ('ｈｔｔｐｓ_FW', 32),
#  ('很_Dfa', 31),
#  ('不足_VH', 31),
#  ('年_Nf', 30),
#  ('退文_VA', 30),
#  ('階_Nf', 30),
#  ('相關_VH', 29),
#  ('程度_Na', 29),
#  ('要_D', 28),
#  ('還_D', 28),
#  ('１_Neu', 27),
#  ('使用_VC', 27),
#  ('其他_Neqa', 27),
#  ('可_D', 27),
#  ('與_Caa', 27),
#  ('自行_D', 27),
#  ('後_Ng', 26),
#  ('二_Neu', 26)]

# %% [markdown]
# #### 2.1.3 高雄版詞意頻表

# %%
# sorting sense frequency tables
kh_tables_sense = list(kh_tables[2].items())
sorted(kh_tables_sense, reverse=True, key=lambda x: x[1])[0:99]
# Out:
# [('：__', 1296),
#  ('，__', 802),
#  ('。__', 408),
#  ('判決__', 408),
#  ('．__', 282),
#  ('原文_04060101_原來的文本。', 259),
#  ('不_05010901_表疑問的語氣，置於句末。', 234),
#  ('水桶__', 165),
#  ('、__', 158),
#  ('屬__', 152),
#  ('］__', 146),
#  ('［__', 144),
#  ('（__', 113),
#  ('６１__', 111),
#  ('）__', 110),
#  ('日_03036209_計算時間的單位。一日為二十四小時。', 106),
#  ('依_04018504_引介遵循的原則。', 98),
#  ('高雄_06047401_位於臺灣南部，介於臺東縣、屏東縣、臺南縣之間的地區。', 91),
#  ('７__', 91),
#  ('或_04001201_連接語意相似的詞組或子句，表選擇關係或並列關係。', 90),
#  ('針對_04017001_引介事件所涉及的特定對象。', 89),
#  ('的_07023402_表領屬關係，用於修飾語和中心語間。', 88),
#  ('規定_06678002_要求他人在進行特定事件時必須遵守的內容。', 86),
#  ('處_03007402_計算部位、地點的單位。', 83),
#  ('故_03015807_表帶有明確意圖做事。', 82),
#  ('者_06641401_具有前述身份或進行前述行為的人或團體。', 78),
#  ('之_04090401_表一般的修飾關係，用於修飾語和中心語間。', 76),
#  ('經_05002105_引介事件進行的過程或方法。', 73),
#  ('板友__', 72),
#  ('內容_06773301_特定事物內部所包含的實質對象。', 70),
#  ('？__', 62),
#  ('已_06668401_表後述事件在說話之前發生或完成。', 62),
#  ('引起_06772201_因使特定對象注意而導致後述結果。', 62),
#  ('爭端__', 62),
#  ('文_05156301_獨立而首尾完整的成篇文字。', 60),
#  ('影射__', 59),
#  ('依_04018505_引介判斷的標準或條件。', 58),
#  ('請_06532302_用客氣的語氣提出後述要求。', 57),
#  ('特定__', 54),
#  ('不當__', 54),
#  ('徵求__', 52),
#  ('族群_06691401_人類由相同語言、種族、地域等文化因素所構成的群體。', 52),
#  ('是_07023505_表後述動作的受事者是前述對象。', 50),
#  ('的_07023408_列舉相類似的事物。', 50),
#  ('或_04001203_表猜測。', 50),
#  ('處_03007401_特定對象所在的地方。', 48),
#  ('新聞_06707702_報導新聞的節目。', 47),
#  ('歧視__', 47),
#  ('／／ｉ__', 46),
#  ('ｉｍｇｕｒ__', 46),
#  ('是_09250001_形容正確的或處理特定事件的作法適當。', 46),
#  ('有_04013807_表肯定事件的發生。', 45),
#  ('有_04013803_後述對象存在。', 45),
#  ('交換__', 43),
#  ('依_04018506_引介特定的觀點。', 43),
#  ('是_09250101_前述事物的代稱。', 42),
#  ('的_07023401_表一般的修飾關係，用於修飾語和中心語間。', 42),
#  ('退文__', 41),
#  ('查_05008402_為了解事件而收集資料。', 41),
#  ('會_04143405_表在通常狀況下，有可能實現。', 40),
#  ('人_05231101_軀幹直立，用雙腳行走的高等動物，具備思考能力，有語言文字，能進行社交活動。', 40),
#  ('被_04011801_引介施事者。', 40),
#  ('內文__', 40),
#  ('次_05048202_計算事件發生的次數的單位。', 39),
#  ('這_05223501_根據說話者說話時所處的時空而言，指稱比較近的後述對象。', 39),
#  ('ｈｔｔｐｓ__', 38),
#  ('了_04005202_表示變化或出現新的情況，置於句末或句中停頓處。', 38),
#  ('之_04090402_表領屬關係，用於修飾語和中心語間。', 38),
#  ('故_03015808_連接因上述原因而得到的後述結果或結論。', 38),
#  ('在_04015702_引介處所。', 37),
#  ('刪_09020201_在特定範圍中去除特定項目或內容。', 37),
#  ('禁止_05050501_制止、不允許作特定動作或行為。', 36),
#  ('應_06722301_表按照道理必須做後述事件。', 36),
#  ('但_06751601_表連接句子的轉折語氣，用來引出命題和前文相對的句子。', 35),
#  ('一_05224201_數目字。整數，最小的正整數。', 34),
#  ('２__', 34),
#  ('篇_03032102_計算文章的單位。', 34),
#  ('一_06727301_事物的全體。', 33),
#  ('檢舉__', 33),
#  ('並_04159701_連接兩對等句子，表示進一層關係。', 33),
#  ('違反_06600101_不遵守後述規定或不履行承諾。', 33),
#  ('交易文__', 33),
#  ('警告__', 33),
#  ('很_05172901_表超過平常的程度。', 31),
#  ('不足__', 31),
#  ('階_07071507_計算音程的單位。', 30),
#  ('一_05224202_序數。順序排在第一。', 30),
#  ('我_05238701_代指說話者。', 29),
#  ('就_05198301_表前述事件為後述事件的充分條件，表示在該條件或情況下自然發展。', 29),
#  ('再_06774402_表接連發生事件中的後述發生事件。', 29),
#  ('年_05229303_計算時間的單位，一年有十二個月。', 29),
#  ('相關__', 29),
#  ('有_04013802_斷定特定對象有後述性質。', 28),
#  ('１__', 28),
#  ('其他_03032801_另外的。', 27),
#  ('違__', 27),
#  ('新聞_06707703_新發生的，大多數人還不知道的消息。', 27),
#  ('／__', 27),
#  ('自行_06606401_表主事者獨自進行後述事件。', 27)]

# %% [markdown]
# ### 2.2 台北板詞頻表、詞類頻表、詞義頻表

# %% [markdown]
# #### 2.2.1 台北板詞頻表

# %%
# sorting word frequency tables
tp_tables = freq_tables(tp_tagged_sense)
tp_tables_word = list(tp_tables[0].items())
sorted(tp_tables_word, reverse=True, key=lambda x: x[1])[0:99]
# Out:
# [('：', 810),
#  ('．', 604),
#  ('，', 346),
#  ('的', 256),
#  ('ｈｔｔｐｓ', 146),
#  ('、', 126),
#  ('。', 119),
#  ('（', 98),
#  ('）', 98),
#  ('時間', 71),
#  ('／／ｐｉｃ', 71),
#  ('ｐｉｍｇ', 71),
#  ('是', 67),
#  ('／／ｗｗｗ', 67),
#  ('台北市', 61),
#  ('一', 58),
#  ('ｊｐｇ', 58),
#  ('食記', 56),
#  ('有', 54),
#  ('地址', 53),
#  ('電話', 53),
#  ('營業', 52),
#  ('ｐｉｘｎｅｔ', 52),
#  ('／／ｊｅｒｅｍｙｃｋｔ２', 51),
#  ('線', 49),
#  ('很', 47),
#  ('和', 47),
#  ('鄰近', 47),
#  ('台北', 46),
#  ('在', 46),
#  ('捷運站', 45),
#  ('ｆａｃｅｂｏｏｋ', 42),
#  ('０２', 41),
#  ('００', 37),
#  ('這', 36),
#  ('粉專', 35),
#  ('都', 33),
#  ('了', 32),
#  ('我', 32),
#  ('每', 31),
#  ('捷運', 30),
#  ('星期一', 29),
#  ('天', 29),
#  ('ｈｔｔｐ', 29),
#  ('信義', 27),
#  ('～', 26),
#  ('不', 25),
#  ('新店', 25),
#  ('淡水', 25),
#  ('１２', 24),
#  ('也', 23),
#  ('松山', 23),
#  ('就', 22),
#  ('日', 22),
#  ('］', 21),
#  ('官網', 21),
#  ('韓式', 20),
#  ('可以', 20),
#  ('中', 20),
#  ('又', 19),
#  ('抹', 19),
#  ('看板', 18),
#  ('１１', 18),
#  ('吃', 18),
#  ('人', 18),
#  ('公休', 18),
#  ('烤', 17),
#  ('大安區', 17),
#  ('到', 17),
#  ('身體', 17),
#  ('茶', 17),
#  ('００ＦＢ', 17),
#  ('；', 17),
#  ('００～２１', 17),
#  ('還', 16),
#  ('來', 16),
#  ('家', 16),
#  ('店', 16),
#  ('著', 16),
#  ('或', 16),
#  ('好', 16),
#  ('及', 15),
#  ('與', 15),
#  ('上', 15),
#  ('次', 15),
#  ('我們', 15),
#  ('之', 15),
#  ('說', 15),
#  ('甜點', 15),
#  ('ＦＢ粉專', 15),
#  ('覺得', 14),
#  ('會', 14),
#  ('３０', 14),
#  ('［', 13),
#  ('咖啡', 13),
#  ('００～２２', 13),
#  ('肉', 12),
#  ('自己', 12),
#  ('車站', 12)]

# %% [markdown]
# #### 2.2.2 台北板詞類頻表

# %%
# sorting pos frequency tables
tp_tables_pos = list(tp_tables[1].items())
sorted(tp_tables_pos, reverse=True, key=lambda x: x[1])[0:99]
# Out:
# [('：_COLONCATEGORY', 810),
#  ('．_PERIODCATEGORY', 604),
#  ('，_COMMACATEGORY', 346),
#  ('的_DE', 246),
#  ('ｈｔｔｐｓ_FW', 143),
#  ('、_PAUSECATEGORY', 126),
#  ('。_PERIODCATEGORY', 119),
#  ('（_PARENTHESISCATEGORY', 98),
#  ('）_PARENTHESISCATEGORY', 98),
#  ('時間_Na', 71),
#  ('／／ｐｉｃ_FW', 71),
#  ('ｐｉｍｇ_FW', 71),
#  ('是_SHI', 67),
#  ('／／ｗｗｗ_FW', 67),
#  ('台北市_Nc', 61),
#  ('一_Neu', 54),
#  ('地址_Na', 53),
#  ('電話_Na', 53),
#  ('有_V_2', 53),
#  ('營業_Nv', 52),
#  ('ｐｉｘｎｅｔ_FW', 52),
#  ('／／ｊｅｒｅｍｙｃｋｔ２_FW', 51),
#  ('線_Na', 49),
#  ('很_Dfa', 47),
#  ('台北_Nc', 46),
#  ('食記_Na', 46),
#  ('捷運站_Nc', 45),
#  ('鄰近_VJ', 45),
#  ('在_P', 44),
#  ('和_Caa', 44),
#  ('ｆａｃｅｂｏｏｋ_FW', 42),
#  ('０２_Neu', 41),
#  ('００_Neu', 37),
#  ('這_Nep', 36),
#  ('ｊｐｇ_Na', 35),
#  ('都_D', 33),
#  ('我_Nh', 32),
#  ('每_Nes', 31),
#  ('捷運_Na', 30),
#  ('星期一_Nd', 29),
#  ('ｈｔｔｐ_FW', 29),
#  ('信義_Na', 27),
#  ('天_Nf', 26),
#  ('不_D', 25),
#  ('新店_Nc', 25),
#  ('淡水_Nc', 25),
#  ('了_Di', 24),
#  ('也_D', 23),
#  ('松山_Nc', 23),
#  ('就_D', 22),
#  ('］_PARENTHESISCATEGORY', 21),
#  ('官網_Na', 21),
#  ('日_Nd', 21),
#  ('韓式_A', 20),
#  ('可以_D', 20),
#  ('ｊｐｇ_FW', 20),
#  ('粉專_Nc', 20),
#  ('看板_Na', 18),
#  ('吃_VC', 18),
#  ('人_Na', 18),
#  ('公休_VH', 18),
#  ('大安區_Nc', 17),
#  ('身體_Na', 17),
#  ('茶_Na', 17),
#  ('００ＦＢ_FW', 17),
#  ('；_SEMICOLONCATEGORY', 17),
#  ('００～２１_Neu', 17),
#  ('還_D', 16),
#  ('烤_VC', 16),
#  ('著_Di', 16),
#  ('或_Caa', 16),
#  ('及_Caa', 15),
#  ('次_Nf', 15),
#  ('我們_Nh', 15),
#  ('之_DE', 15),
#  ('店_Nc', 15),
#  ('說_VE', 15),
#  ('甜點_Na', 15),
#  ('粉專_Na', 15),
#  ('ＦＢ粉專_Nc', 15),
#  ('覺得_VK', 14),
#  ('會_D', 14),
#  ('抹_VC', 14),
#  ('３０_Neu', 14),
#  ('［_PARENTHESISCATEGORY', 13),
#  ('家_Nf', 13),
#  ('咖啡_Na', 13),
#  ('～_Caa', 13),
#  ('～_Nd', 13),
#  ('１２_Nd', 13),
#  ('００～２２_Neu', 13),
#  ('肉_Na', 12),
#  ('上_Ncd', 12),
#  ('好_VH', 12),
#  ('自己_Nh', 12),
#  ('車站_Nc', 12),
#  ('壓力_Na', 12),
#  ('信義區_Nc', 12),
#  ('星期二_Nd', 12)]

# %% [markdown]
# #### 2.2.3 台北板詞義頻表

# %%
# sorting sense frequency tables
tp_tables_sense = list(tp_tables[2].items())
sorted(tp_tables_sense, reverse=True, key=lambda x: x[1])[0:99]
# Out:
# [('：__', 810),
#  ('．__', 604),
#  ('，__', 346),
#  ('ｈｔｔｐｓ__', 146),
#  ('、__', 126),
#  ('。__', 119),
#  ('（__', 98),
#  ('）__', 98),
#  ('的_07023408_列舉相類似的事物。', 88),
#  ('的_07023402_表領屬關係，用於修飾語和中心語間。', 86),
#  ('／／ｐｉｃ__', 71),
#  ('ｐｉｍｇ__', 71),
#  ('／／ｗｗｗ__', 67),
#  ('台北市_06679601_位於臺灣北部，為臺灣政治、經濟中心。', 61),
#  ('ｊｐｇ__', 58),
#  ('食記__', 56),
#  ('地址__', 53),
#  ('營業__', 52),
#  ('的_07023401_表一般的修飾關係，用於修飾語和中心語間。', 52),
#  ('ｐｉｘｎｅｔ__', 52),
#  ('／／ｊｅｒｅｍｙｃｋｔ２__', 51),
#  ('線_06522708_比喻特定通訊線路。', 49),
#  ('很_05172901_表超過平常的程度。', 47),
#  ('鄰近__', 47),
#  ('台北_06708401_位於臺灣北部的城市，為臺灣的政治經濟中心。', 46),
#  ('是_09250101_前述事物的代稱。', 46),
#  ('捷運站__', 45),
#  ('電話_06694101_利用電傳輸語音訊號，使兩地間能互相通話的通訊系統與裝置。', 44),
#  ('和_04156201_連接並列的詞組，表做連接的事件同時成立。', 44),
#  ('時間_06560103_時間的一個段落。', 42),
#  ('ｆａｃｅｂｏｏｋ__', 42),
#  ('０２__', 41),
#  ('００__', 37),
#  ('粉專__', 35),
#  ('在_04015702_引介處所。', 32),
#  ('有_04013803_後述對象存在。', 32),
#  ('捷運__', 30),
#  ('時間_06560102_時點。', 29),
#  ('星期一__', 29),
#  ('這_05223501_根據說話者說話時所處的時空而言，指稱比較近的後述對象。', 29),
#  ('ｈｔｔｐ__', 29),
#  ('信義__', 27),
#  ('天_05225405_計算時間的單位。一天為二十四小時。', 26),
#  ('～__', 26),
#  ('不_05010901_表疑問的語氣，置於句末。', 25),
#  ('新店__', 25),
#  ('淡水_08037701_鎮名，位臺北縣內。', 25),
#  ('一_05224201_數目字。整數，最小的正整數。', 24),
#  ('１２__', 24),
#  ('都_05196901_表全部。', 23),
#  ('松山__', 23),
#  ('每_03028202_表只要。', 22),
#  ('］__', 21),
#  ('官網__', 21),
#  ('韓式__', 20),
#  ('我_05238701_代指說話者。', 20),
#  ('日_03036207_地球自轉一周所需的時間。', 20),
#  ('看板__', 18),
#  ('１１__', 18),
#  ('吃_05227001_使物體經過口中吞入體內。', 18),
#  ('公休__', 18),
#  ('大安區__', 17),
#  ('也_06774601_表所描述的對象屬於同一類。', 17),
#  ('００ＦＢ__', 17),
#  ('；__', 17),
#  ('００～２１__', 17),
#  ('了_05003602_時態標記。表前述對象對該事件或動作有實現的能力。', 16),
#  ('人_05231101_軀幹直立，用雙腳行走的高等動物，具備思考能力，有語言文字，能進行社交活動。', 16),
#  ('及_03020201_連接並列的詞組，表做連接的事件同時成立。', 15),
#  ('我們_05224801_代指說話者和聽話者雙方。', 15),
#  ('店_07027301_販賣商品或提供特定服務的地方。', 15),
#  ('著_04005101_時態標記。表前述動作持續進行。', 15),
#  ('甜點__', 15),
#  ('ＦＢ粉專__', 15),
#  ('是_07023505_表後述動作的受事者是前述對象。', 14),
#  ('或_04001201_連接語意相似的詞組或子句，表選擇關係或並列關係。', 14),
#  ('抹_07037601_將油膏、粉末或液體塗抹在物體表面。', 14),
#  ('３０__', 14),
#  ('［__', 13),
#  ('會_04143405_表在通常狀況下，有可能實現。', 13),
#  ('有_04013802_斷定特定對象有後述性質。', 13),
#  ('咖啡__', 13),
#  ('００～２２__', 13),
#  ('烤_06512501_接近熱源利用熱能使食物變熟。', 12),
#  ('肉_05222903_作為食物的動物肉。', 12),
#  ('次_05048202_計算事件發生的次數的單位。', 12),
#  ('一_06727301_事物的全體。', 12),
#  ('上_04081314_事件的發生在前述事物的範圍內。', 12),
#  ('又_04000901_連接兩對等詞組，表兩種狀況同時存在。', 12),
#  ('我_05238702_代指說話者所擁有的。', 12),
#  ('信義區__', 12),
#  ('家_06708312_計算公司行號或商店的單位。', 12),
#  ('星期二__', 12),
#  ('板南線__', 12),
#  ('之_04090402_表領屬關係，用於修飾語和中心語間。', 11),
#  ('可以_06715202_表後述事件為聽話者可以選擇自己進行的事件之一。', 11),
#  ('身體_06664901_有機體特別是人或動物軀體的總稱，人或動物生理組織的整體或專指動物的軀幹。', 11),
#  ('茶_06706303_用茶葉沏成或煮成的飲料。', 11),
#  ('起司__', 11)]
