# %% [markdown]
# ### 1. 處理前準備

# %%
import json
import pickle
import CwnGraph, DistilTag, CwnSenseTagger
from DistilTag import DistilTag  
from CwnSenseTagger import senseTag
# Out:
# /home/andrea/py37/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# 半形轉全形函數 (斷詞需要全形符號才能運作)
def strB2Q(ustring):
    ss = []
    for s in ustring:
        rstring = ""
        for uchar in s:
            inside_code = ord(uchar)
            if inside_code == 32:
                inside_code = 12288
            elif (inside_code >= 33 and inside_code <= 126):
                inside_code += 65248
            rstring += chr(inside_code)
        ss.append(rstring)
    return ''.join(ss)

# %%
# 定義 senseTag2 函數
def senseTag2(tagged):
    out = []
    for t in tagged:
        try:
            tt = senseTag([t])
        except:
            continue
        out.append(tt)
    return out

# %% [markdown]
# ### 2. Load Data

# %%
with open("kh_tagged.pkl", "rb") as f:
    kh_tagged = pickle.load(f)
    
with open("kh_tagged_sense.pkl", "rb") as f:
    kh_tagged_sense = pickle.load(f)
    
with open("tp_tagged.pkl", "rb") as f:
    tp_tagged = pickle.load(f)

# %% [markdown]
# ### 3. Make Frequency Lists

# %%
# making frequency tables
def freq_tables(sense_tagged_data):
    word_freq = {}
    pos_freq = {}
    sense_freq = {}

    for post in sense_tagged_data:
        for sent in post:
            for form, pos, sense_id, sense_def in sent:

                if form not in word_freq:
                    word_freq[form] = 1
                else:
                    word_freq[form] += 1

                word_pos = f"{form}_{pos}"
                if word_pos not in pos_freq:
                    pos_freq[word_pos] = 1
                else:
                    pos_freq[word_pos] += 1

                word_sense = f"{form}_{sense_id}_{sense_def}"
                if word_sense not in sense_freq:
                    sense_freq[word_sense] = 1
                else:
                    sense_freq[word_sense] += 1
        
    return word_freq, pos_freq, sense_freq

# %% [markdown]
# ### 4. 高雄板詞頻表、詞類頻表、詞義頻表

# %% [markdown]
# #### 4.1 高雄板詞頻表

# %%
# sorting word frequency tables
kh_tables = freq_tables(kh_tagged_sense)
kh_tables_word = list(kh_tables[0].items())
sorted(kh_tables_word, reverse=True, key=lambda x: x[1])
# Out:
# [('：', 1296),
#  ('，', 802),
#  ('判決', 424),
#  ('。', 408),
#  ('．', 282),
#  ('原文', 259),
#  ('的', 249),
#  ('不', 237),
#  ('依', 210),
#  ('水桶', 165),
#  ('、', 158),
#  ('或', 153),
#  ('屬', 152),
#  ('處', 150),
#  ('］', 146),
#  ('［', 144),
#  ('是', 141),
#  ('之', 140),
#  ('一', 131),
#  ('有', 127),
#  ('故', 121),
#  ('（', 113),
#  ('６１', 111),
#  ('）', 110),
#  ('日', 107),
#  ('新聞', 100),
#  ('高雄', 95),
#  ('７', 91),
#  ('針對', 89),
#  ('規定', 88),
#  ('就', 85),
#  ('者', 80),
#  ('了', 78),
#  ('經', 73),
#  ('板友', 72),
#  ('內容', 71),
#  ('文', 70),
#  ('在', 68),
#  ('？', 62),
#  ('已', 62),
#  ('引起', 62),
#  ('爭端', 62),
#  ('請', 59),
#  ('影射', 59),
#  ('上', 57),
#  ('以', 54),
#  ('特定', 54),
#  ('不當', 54),
#  ('為', 53),
#  ('徵求', 52),
#  ('族群', 52),
#  ('無', 51),
#  ('人', 50),
#  ('會', 47),
#  ('這', 47),
#  ('並', 47),
#  ('歧視', 47),
#  ('／／ｉ', 46),
#  ('ｉｍｇｕｒ', 46),
#  ('我', 45),
#  ('但', 43),
#  ('次', 43),
#  ('都', 43),
#  ('交換', 43),
#  ('查', 42),
#  ('退文', 41),
#  ('被', 40),
#  ('內文', 40),
#  ('也', 39),
#  ('內', 39),
#  ('文章', 39),
#  ('個', 39),
#  ('警告', 39),
#  ('ｈｔｔｐｓ', 38),
#  ('與', 37),
#  ('刪', 37),
#  ('禁止', 36),
#  ('應', 36),
#  ('同', 36),
#  ('可以', 35),
#  ('於', 35),
#  ('２', 34),
#  ('再', 34),
#  ('年', 34),
#  ('篇', 34),
#  ('檢舉', 33),
#  ('違反', 33),
#  ('交易文', 33),
#  ('可', 32),
#  ('好', 31),
#  ('很', 31),
#  ('要', 31),
#  ('不足', 31),
#  ('階', 30),
#  ('多', 29),
#  ('相關', 29),
#  ('還', 29),
#  ('程度', 29),
#  ('１', 28),
#  ('使用', 28),
#  ('且', 28),
#  ('其他', 27),
#  ('違', 27),
#  ('／', 27),
#  ('自行', 27),
#  ('又', 26),
#  ('後', 26),
#  ('二', 26),
#  ('看板', 26),
#  ('錯誤', 26),
#  ('及', 25),
#  ('資訊', 25),
#  ('處理', 25),
#  ('你', 25),
#  ('未', 24),
#  ('非', 24),
#  ('個人', 24),
#  ('他人', 24),
#  ('到', 23),
#  ('沒', 23),
#  ('推', 23),
#  ('行為', 23),
#  ('４', 23),
#  ('兩', 23),
#  ('部分', 23),
#  ('～', 23),
#  ('蟑螂', 23),
#  ('天', 22),
#  ('說', 22),
#  ('時間', 22),
#  ('３', 22),
#  ('中', 22),
#  ('評論', 22),
#  ('高雄人', 22),
#  ('嗎', 21),
#  ('板規', 21),
#  ('目前', 21),
#  ('７１', 21),
#  ('時', 20),
#  ('過', 20),
#  ('來', 20),
#  ('需', 20),
#  ('買賣', 20),
#  ('若', 19),
#  ('如果', 19),
#  ('５', 19),
#  ('板主', 19),
#  ('輕軌', 19),
#  ('定義', 19),
#  ('３０', 19),
#  ('７日', 19),
#  ('累計為', 19),
#  ('什麼', 18),
#  ('用', 18),
#  ('能', 18),
#  ('只', 18),
#  ('２２', 18),
#  ('範圍', 18),
#  ('對', 18),
#  ('刪除', 18),
#  ('推文', 18),
#  ('Ｋａｏｈｓｉｕｎｇ', 18),
#  ('陳其邁', 18),
#  ('底下', 18),
#  ('廣告文', 18),
#  ('罰則', 18),
#  ('等', 18),
#  ('本', 17),
#  ('真的', 17),
#  ('討論', 17),
#  ('地點', 17),
#  ('違規', 17),
#  ('查閱', 17),
#  ('宣告', 17),
#  ('該', 17),
#  ('發覺', 17),
#  ('規定處', 17),
#  ('越', 17),
#  ('才', 16),
#  ('８', 16),
#  ('６', 16),
#  ('知道', 16),
#  ('看', 16),
#  ('張貼', 16),
#  ('發文', 16),
#  ('具', 16),
#  ('逾', 16),
#  ('得', 15),
#  ('現在', 15),
#  ('板', 15),
#  ('換', 15),
#  ('１０', 15),
#  ('做', 15),
#  ('玩樂文', 15),
#  ('救濟', 15),
#  ('大家', 14),
#  ('種', 14),
#  ('沒有', 14),
#  ('大', 14),
#  ('去', 14),
#  ('則', 14),
#  ('而', 14),
#  ('禁發', 14),
#  ('試用', 14),
#  ('三', 14),
#  ('爭議', 14),
#  ('４％', 14),
#  ('貶抑', 14),
#  ('戰', 14),
#  ('嘲諷', 14),
#  ('想', 13),
#  ('那', 13),
#  ('可能', 13),
#  ('跟', 13),
#  ('方式', 13),
#  ('還是', 13),
#  ('活動', 13),
#  ('當', 13),
#  ('直接', 13),
#  ('政治', 13),
#  ('連結', 13),
#  ('說明', 13),
#  ('前', 13),
#  ('規範', 13),
#  ('仍', 13),
#  ('韓粉', 13),
#  ('５４', 13),
#  ('不幸', 13),
#  ('他', 12),
#  ('小', 12),
#  ('所以', 12),
#  ('問題', 12),
#  ('公告', 12),
#  ('如', 12),
#  ('轉錄', 12),
#  ('原因', 12),
#  ('自己', 12),
#  ('怎麼', 12),
#  ('發表', 12),
#  ('１８', 12),
#  ('僅', 12),
#  ('》', 12),
#  ('以上', 12),
#  ('確實', 12),
#  ('改進', 12),
#  ('無法', 12),
#  ('高雄板', 11),
#  ('市長', 11),
#  ('／／ｉｍｇｕｒ', 11),
#  ('這樣', 11),
#  ('給', 11),
#  ('吃', 11),
#  ('每', 11),
#  ('因', 11),
#  ('車輛', 11),
#  ('階段', 11),
#  ('綠', 11),
#  ('讓', 11),
#  ('政治文', 11),
#  ('愛', 11),
#  ('管理', 11),
#  ('轉讓', 11),
#  ('《', 11),
#  ('挑釁', 11),
#  ('帳號', 11),
#  ('詳述', 11),
#  ('贈送', 10),
#  ('一直', 10),
#  ('應該', 10),
#  ('狀況', 10),
#  ('看到', 10),
#  ('幾', 10),
#  ('需要', 10),
#  ('帶', 10),
#  ('最', 10),
#  ('算', 10),
#  ('因為', 10),
#  ('一樣', 10),
#  ('韓', 10),
#  ('參閱', 10),
#  ('資料', 10),
#  ('分身', 10),
#  ('ｐｎｇｈｔｔｐｓ', 10),
#  ('啊', 10),
#  ('作為', 10),
#  ('字', 10),
#  ('１４', 10),
#  ('同意', 10),
#  ('判定', 10),
#  ('閒聊', 10),
#  ('併退文', 10),
#  ('啦', 10),
#  ('邁邁', 10),
#  ('引', 10),
#  ('１０／０９２２', 10),
#  ('ｊｐｇ', 9),
#  ('買', 9),
#  ('堆', 9),
#  ('家', 9),
#  ('找', 9),
#  ('將', 9),
#  ('１１', 9),
#  ('很多', 9),
#  ('完整', 9),
#  ('公開', 9),
#  ('物品', 9),
#  ('先', 9),
#  ('亂', 9),
#  ('由', 9),
#  ('檢舉方', 9),
#  ('覺得', 9),
#  ('Ａ７', 9),
#  ('以下', 9),
#  ('原', 9),
#  ('此', 9),
#  ('併', 9),
#  ('５２', 9),
#  ('言論', 9),
#  ('是否', 9),
#  ('今天', 8),
#  ('送', 8),
#  ('顏色', 8),
#  ('噴', 8),
#  ('開始', 8),
#  ('們', 8),
#  ('出現', 8),
#  ('人物', 8),
#  ('其', 8),
#  ('晚上', 8),
#  ('太', 8),
#  ('韓導', 8),
#  ('最後', 8),
#  ('標題', 8),
#  ('營運', 8),
#  ('整合', 8),
#  ('媒體', 8),
#  ('點', 8),
#  ('第二', 8),
#  ('公司', 8),
#  ('進行', 8),
#  ('工作', 8),
#  ('四', 8),
#  ('涉及', 8),
#  ('金錢', 8),
#  ('ｈｔｔｐ', 8),
#  ('貼', 8),
#  ('位', 8),
#  ('把', 8),
#  ('這麼', 8),
#  ('真', 8),
#  ('列車', 8),
#  ('票券', 8),
#  ('３１', 8),
#  ('Ａ１０', 8),
#  ('加罰', 8),
#  ('懲處', 8),
#  ('高雄點', 8),
#  ('適用', 8),
#  ('１７', 8),
#  ('辦法', 8),
#  ('３３', 8),
#  ('提出', 8),
#  ('條款', 8),
#  ('爆', 8),
#  ('藥', 8),
#  ('３９', 8),
#  ('呢', 7),
#  ('吧', 7),
#  ('到期', 7),
#  ('站', 7),
#  ('信', 7),
#  ('以前', 7),
#  ('暖', 7),
#  ('咖哩', 7),
#  ('高雄市', 7),
#  ('００', 7),
#  ('其實', 7),
#  ('怕', 7),
#  ('為主', 7),
#  ('從', 7),
#  ('和', 7),
#  ('發言', 7),
#  ('Ａ', 7),
#  ('路段', 7),
#  ('系統', 7),
#  ('全', 7),
#  ('更', 7),
#  ('來信', 7),
#  ('交易', 7),
#  ('水', 7),
#  ('結果', 7),
#  ('各', 7),
#  ('您', 7),
#  ('八卦板', 7),
#  ('貓咪', 7),
#  ('交換物', 7),
#  ('５０', 7),
#  ('稱呼', 7),
#  ('但是', 7),
#  ('不會', 7),
#  ('５１', 7),
#  ('中時', 7),
#  ('新聞網', 7),
#  ('小心', 7),
#  ('１５', 7),
#  ('２０', 7),
#  ('判處', 7),
#  ('包含', 7),
#  ('開放', 7),
#  ('折價券', 7),
#  ('３４', 7),
#  ('４４', 7),
#  ('達', 7),
#  ('件', 7),
#  ('７２', 7),
#  ('雖', 7),
#  ('提醒', 7),
#  ('５００', 7),
#  ('高雄版', 7),
#  ('升級', 7),
#  ('像', 7),
#  ('０９／１５１９', 7),
#  ('意味', 7),
#  ('０９／２６１２', 7),
#  ('１０／０１１２', 7),
#  ('補', 6),
#  ('謝謝', 6),
#  ('著', 6),
#  ('或許', 6),
#  ('下', 6),
#  ('試', 6),
#  ('面交', 6),
#  ('幫', 6),
#  ('另外', 6),
#  ('條', 6),
#  ('比較', 6),
#  ('時期', 6),
#  ('發', 6),
#  ('網路', 6),
#  ('認為', 6),
#  ('這些', 6),
#  ('任何', 6),
#  ('不要', 6),
#  ('洗', 6),
#  ('提供', 6),
#  ('新', 6),
#  ('達成', 6),
#  ('２１', 6),
#  ('民眾', 6),
#  ('工程', 6),
#  ('政府', 6),
#  ('不同', 6),
#  ('查證', 6),
#  ('行', 6),
#  ('品質', 6),
#  ('工廠', 6),
#  ('欲', 6),
#  ('張', 6),
#  ('或是', 6),
#  ('月', 6),
#  ('發生', 6),
#  ('罵', 6),
#  ('寫', 6),
#  ('查中', 6),
#  ('週', 6),
#  ('自由', 6),
#  ('法律', 6),
#  ('七', 6),
#  ('視為', 6),
#  ('項', 6),
#  ('部份', 6),
#  ('類', 6),
#  ('置', 6),
#  ('板面', 6),
#  ('交換文', 6),
#  ('３２', 6),
#  ('上述', 6),
#  ('４１', 6),
#  ('４３', 6),
#  ('宣傳', 6),
#  ('六', 6),
#  ('申訴', 6),
#  ('受理', 6),
#  ('均', 6),
#  ('判斷', 6),
#  ('字數', 6),
#  ('改善', 6),
#  ('登入', 6),
#  ('死', 6),
#  ('噁心', 6),
#  ('改正', 6),
#  ('／／ｔｉｎｙｕｒｌ', 6),
#  ('４０', 6),
#  ('第一', 6),
#  ('推ｑａｚｅｄｃ', 6),
#  ('幸福', 6),
#  ('Ｌｅｅｈｅａｖｅｎ', 6),
#  ('ｎｉｃｋｙ５１', 6),
#  ('分享', 6),
#  ('開', 6),
#  ('一起', 6),
#  ('志工', 6),
#  ('輸血', 6),
#  ('請問', 5),
#  ('地方', 5),
#  ('誰', 5),
#  ('看看', 5),
#  ('附近', 5),
#  ('蠻', 5),
#  ('紀錄', 5),
#  ('皆', 5),
#  ('詳細', 5),
#  ('些', 5),
#  ('食物', 5),
#  ('６５', 5),
#  ('名稱', 5),
#  ('店面', 5),
#  ('一些', 5),
#  ('難', 5),
#  ('八', 5),
#  ('方便', 5),
#  ('違者', 5),
#  ('小時', 5),
#  ('作者', 5),
#  ('高市', 5),
#  ('表示', 5),
#  ('目標', 5),
#  ('食品', 5),
#  ('日期', 5),
#  ('處分', 5),
#  ('拿', 5),
#  ('飲料', 5),
#  ('版友', 5),
#  ('某', 5),
#  ('喔', 5),
#  ('某些', 5),
#  ('出來', 5),
#  ('板務', 5),
#  ('而已', 5),
#  ('報導', 5),
#  ('２９', 5),
#  ('超過', 5),
#  ('首犯', 5),
#  ('生活', 5),
#  ('１２', 5),
#  ('回文', 5),
#  ('情節', 5),
#  ('即', 5),
#  ('租賃', 5),
#  ('底', 5),
#  ('販賣', 5),
#  ('２４', 5),
#  ('２５', 5),
#  ('關於', 5),
#  ('玩樂', 5),
#  ('情形', 5),
#  ('受', 5),
#  ('商業', 5),
#  ('廣告', 5),
#  ('閱讀', 5),
#  ('刪文', 5),
#  ('刻意', 5),
#  ('理由', 5),
#  ('分類', 5),
#  ('處份', 5),
#  ('６０', 5),
#  ('確定', 5),
#  ('修正', 5),
#  ('查詢', 5),
#  ('所', 5),
#  ('３７', 5),
#  ('智障', 5),
#  ('３８', 5),
#  ('４７', 5),
#  ('記得', 5),
#  ('叫', 5),
#  ('美', 5),
#  ('跑出來', 5),
#  ('詞彙', 5),
#  ('不可', 5),
#  ('０９／１０２２', 5),
#  ('引戰', 5),
#  ('推ＨＡＮＡＸＡＬＩＣＥ', 5),
#  ('５６', 5),
#  ('５７', 5),
#  ('我們', 5),
#  ('垃圾', 5),
#  ('察覺', 5),
#  ('功成身退', 5),
#  ('憨粉', 5),
#  ('肺', 5),
#  ('照片', 4),
#  ('ｊｐｇｈｔｔｐｓ', 4),
#  ('發現', 4),
#  ('鄉民', 4),
#  ('味道', 4),
#  ('有效', 4),
#  ('已經', 4),
#  ('回', 4),
#  ('有沒有', 4),
#  ('外', 4),
#  ('辦', 4),
#  ('好像', 4),
#  ('過期', 4),
#  ('有關', 4),
#  ('向', 4),
#  ('根本', 4),
#  ('的話', 4),
#  ('簡單', 4),
#  ('約', 4),
#  ('豬肉', 4),
#  ('相同', 4),
#  ('炸', 4),
#  ('時候', 4),
#  ('懂', 4),
#  ('講', 4),
#  ('酸', 4),
#  ('只是', 4),
#  ('ｓｉｍｏｎｊｅｎ', 4),
#  ('退', 4),
#  ('新增', 4),
#  ('機電', 4),
#  ('階段性', 4),
#  ('新聞文', 4),
#  ('詞', 4),
#  ('捷運局', 4),
#  ('至', 4),
#  ('；', 4),
#  ('雖然', 4),
#  ('第三', 4),
#  ('確認', 4),
#  ('代表', 4),
#  ('後續', 4),
#  ('２０２０年', 4),
#  ('空間', 4),
#  ('惡意', 4),
#  ('注意', 4),
#  ('聯絡', 4),
#  ('特別', 4),
#  ('車站', 4),
#  ('想要', 4),
#  ('夠', 4),
#  ('平衡', 4),
#  ('那些', 4),
#  ('造成', 4),
#  ('何', 4),
#  ('ｐｎｇ', 4),
#  ('起來', 4),
#  ('太多', 4),
#  ('編號', 4),
#  ('救援', 4),
#  ('對象', 4),
#  ('性別', 4),
#  ('動物', 4),
#  ('醫院', 4),
#  ('４６', 4),
#  ('網軍', 4),
#  ('公關', 4),
#  ('用語', 4),
#  ('不妥', 4),
#  ('含', 4),
#  ('２３', 4),
#  ('查發文', 4),
#  ('造謠', 4),
#  ('分鐘', 4),
#  ('點數', 4),
#  ('屬於', 4),
#  ('台灣', 4),
#  ('１３', 4),
#  ('員工', 4),
#  ('買賣區', 4),
#  ('贈品', 4),
#  ('徵', 4),
#  ('註明', 4),
#  ('亦', 4),
#  ('玩', 4),
#  ('樂文', 4),
#  ('限制', 4),
#  ('至多', 4),
#  ('攻擊', 4),
#  ('影響', 4),
#  ('權利', 4),
#  ('所有', 4),
#  ('附上', 4),
#  ('作', 4),
#  ('期間', 4),
#  ('合併', 4),
#  ('重複', 4),
#  ('３６５０', 4),
#  ('累犯', 4),
#  ('主帳號', 4),
#  ('相似', 4),
#  ('回覆', 4),
#  ('詢問', 4),
#  ('他們', 4),
#  ('起訴', 4),
#  ('個資', 4),
#  ('明確', 4),
#  ('支持', 4),
#  ('２６', 4),
#  ('轉', 4),
#  ('０９／０６０７', 4),
#  ('４８', 4),
#  ('歲', 4),
#  ('幫忙', 4),
#  ('屬有', 4),
#  ('打', 4),
#  ('一定', 4),
#  ('腦粉', 4),
#  ('丁允恭', 4),
#  ('豬', 4),
#  ('共', 4),
#  ('別', 4),
#  ('０９／１００９', 4),
#  ('哪', 4),
#  ('推ｂａｎａｎａ２４６', 4),
#  ('ｅｇｇｏｍｅｇａ', 4),
#  ('白', 4),
#  ('趴', 4),
#  ('生物', 4),
#  ('０９', 4),
#  ('錢', 4),
#  ('暫不', 4),
#  ('０９／１１１４', 4),
#  ('檢討', 4),
#  ('０９／１１１３', 4),
#  ('領', 4),
#  ('ｃａｒｅ', 4),
#  ('繼續', 4),
#  ('０７', 4),
#  ('思考', 4),
#  ('搞', 4),
#  ('管', 4),
#  ('噓ｒｅｂｕｉｌｄＭｏｄｅｌ', 4),
#  ('給予', 4),
#  ('節錄', 4),
#  ('推ａｍｇｎ９９７', 4),
#  ('推ｓｉｇｎｏｒｒ', 4),
#  ('０９／１６１９', 4),
#  ('爽', 4),
#  ('５５', 4),
#  ('冷氣', 4),
#  ('南部', 4),
#  ('潑', 4),
#  ('民宅', 4),
#  ('月餅', 4),
#  ('２８', 4),
#  ('第１５', 4),
#  ('朝聖', 4),
#  ('快', 4),
#  ('地', 4),
#  ('崩潰', 4),
#  ('蘇光頭', 4),
#  ('卵', 4),
#  ('廢物', 4),
#  ('報名', 4),
#  ('感謝', 3),
#  ('氣球', 3),
#  ('歌', 3),
#  ('小朋友', 3),
#  ('感覺', 3),
#  ('溫馨', 3),
#  ('非常', 3),
#  ('香水', 3),
#  ('總', 3),
#  ('價值', 3),
#  ('希望', 3),
#  ('索取', 3),
#  ('ｃｏｍ／', 3),
#  ('期限', 3),
#  ('國小', 3),
#  ('樹', 3),
#  ('蘋果', 3),
#  ('大概', 3),
#  ('網購', 3),
#  ('配合', 3),
#  ('心得', 3),
#  ('像是', 3),
#  ('常', 3),
#  ('路', 3),
#  ('這邊', 3),
#  ('左右', 3),
#  ('建議', 3),
#  ('變成', 3),
#  ('１４０', 3),
#  ('元', 3),
#  ('雙主菜', 3),
#  ('加', 3),
#  ('咖哩飯', 3),
#  ('意外', 3),
#  ('湯汁', 3),
#  ('口', 3),
#  ('不錯', 3),
#  ('財', 3),
#  ('操作', 3),
#  ('事', 3),
#  ('利用', 3),
#  ('標示', 3),
#  ('長', 3),
#  ('網址', 3),
#  ('網友', 3),
#  ('／／ｗｗｗ', 3),
#  ('ｃｏｍ', 3),
#  ('車', 3),
#  ('上線', 3),
#  ('來源', 3),
#  ('中央社', 3),
#  ('更新', 3),
#  ('記者', 3),
#  ('明天', 3),
#  ('測試', 3),
#  ('作業', 3),
#  ('方', 3),
#  ('線', 3),
#  ('城市', 3),
#  ('環境', 3),
#  ('自刪', 3),
#  ('楠梓', 3),
#  ('烘碗機', 3),
#  ('ｐｔｔ', 3),
#  ('收取', 3),
#  ('眼鏡', 3),
#  ('慘', 3),
#  ('戴', 3),
#  ('過去', 3),
#  ('拜託', 3),
#  ('洽中', 3),
#  ('健身', 3),
#  ('杯', 3),
#  ('皮革', 3),
#  ('ＩＤ', 3),
#  ('至於', 3),
#  ('ＰＯ', 3),
#  ('情況', 3),
#  ('一下', 3),
#  ('柯韓粉', 3),
#  ('首先', 3),
#  ('貼文', 3),
#  ('標籤', 3),
#  ('敢', 3),
#  ('當年', 3),
#  ('實在', 3),
#  ('物資', 3),
#  ('告知', 3),
#  ('隻', 3),
#  ('正常', 3),
#  ('今', 3),
#  ('平穩', 3),
#  ('起', 3),
#  ('比', 3),
#  ('緊急', 3),
#  ('１０／３１', 3),
#  ('１１／０１２３', 3),
#  ('主', 3),
#  ('她', 3),
#  ('侮辱', 3),
#  ('對於', 3),
#  ('柯文哲', 3),
#  ('選擇', 3),
#  ('提到', 3),
#  ('歷史', 3),
#  ('唷', 3),
#  ('疏失', 3),
#  ('原來', 3),
#  ('最近', 3),
#  ('北', 3),
#  ('鳳山', 3),
#  ('規則', 3),
#  ('娛樂', 3),
#  ('事件', 3),
#  ('無關', 3),
#  ('中華民國', 3),
#  ('信件', 3),
#  ('１／２１', 3),
#  ('１６', 3),
#  ('勿', 3),
#  ('手動置底', 3),
#  ('特殊', 3),
#  ('需求', 3),
#  ('票據', 3),
#  ('票根', 3),
#  ('２／２１', 3),
#  ('簽名檔', 3),
#  ('合購', 3),
#  ('形式', 3),
#  ('例如', 3),
#  ('間隔', 3),
#  ('１／１１', 3),
#  ('限定', 3),
#  ('人文', 3),
#  ('課程', 3),
#  ('要求', 3),
#  ('版', 3),
#  ('註', 3),
#  ('公告文', 3),
#  ('違法', 3),
#  ('臨時', 3),
#  ('任意', 3),
#  ('地區', 3),
#  ('申請', 3),
#  ('許可', 3),
#  ('得以', 3),
#  ('符合', 3),
#  ('必要', 3),
#  ('明知', 3),
#  ('故犯', 3),
#  ('６１４', 3),
#  ('論', 3),
#  ('案件', 3),
#  ('記錄', 3),
#  ('７５', 3),
#  ('不滿', 3),
#  ('程序', 3),
#  ('加倍', 3),
#  ('規避', 3),
#  ('尚未', 3),
#  ('移除', 3),
#  ('八卦版', 3),
#  ('私人', 3),
#  ('第四', 3),
#  ('首', 3),
#  ('符號', 3),
#  ('文具', 3),
#  ('１９', 3),
#  ('黑', 3),
#  ('０９／０４１５', 3),
#  ('邁', 3),
#  ('鋪路', 3),
#  ('市府', 3),
#  ('０～１９９', 3),
#  ('明白', 3),
#  ('臭', 3),
#  ('推Ｓｕｂｌｉｍｉｎａｌ', 3),
#  ('ＸＥ０９／１０１１', 3),
#  ('０９／１０１１', 3),
#  ('０９／１０１５', 3),
#  ('名狀', 3),
#  ('昆蟲類', 3),
#  ('昆蟲', 3),
#  ('反對', 3),
#  ('４２', 3),
#  ('高雄板引', 3),
#  ('３６', 3),
#  ('原由', 3),
#  ('糞', 3),
#  ('９／２７', 3),
#  ('．ｃｏｍ／ｙ６９ｄｗｊａｎ', 3),
#  ('解', 3),
#  ('０９／１１１９', 3),
#  ('騎車', 3),
#  ('笑死', 3),
#  ('ｗｅｃａｒｅ', 3),
#  ('粉', 3),
#  ('事實', 3),
#  ('０９／１１２３', 3),
#  ('５６ｓａｎｗａｎ', 3),
#  ('卻', 3),
#  ('知', 3),
#  ('存在', 3),
#  ('騙', 3),
#  ('乙烯', 3),
#  ('外洩', 3),
#  ('便當', 3),
#  ('選民', 3),
#  ('０９／１３１１', 3),
#  ('增', 3),
#  ('０９／１２０６', 3),
#  ('ｑａｚｅｄｃ', 3),
#  ('初犯', 3),
#  ('換出', 3),
#  ('０３', 3),
#  ('挺', 3),
#  ('區', 3),
#  ('守', 3),
#  ('規矩', 3),
#  ('０９／１８０９', 3),
#  ('柯粉', 3),
#  ('０９／１６１８', 3),
#  ('ｓｉｇｎｏｒｒ', 3),
#  ('觀察', 3),
#  ('爸爸', 3),
#  ('人家', 3),
#  ('０９／２４２２', 3),
#  ('０９／２４２３', 3),
#  ('賤', 3),
#  ('標準', 3),
#  ('不得', 3),
#  ('低端', 3),
#  ('愛河', 3),
#  ('５５ｎｉｃｋｙ５１', 3),
#  ('煩請', 3),
#  ('浮屍', 3),
#  ('０９／２８０１', 3),
#  ('血', 3),
#  ('推ＧｏＧｏＪｏｅ', 3),
#  ('它', 3),
#  ('闖', 3),
#  ('０９／２６２３', 3),
#  ('爭議性', 3),
#  ('溫暖', 3),
#  ...]

# %% [markdown]
# #### 4.2 高雄板詞類頻表

# %%
# sorting pos frequency tables
kh_tables_pos = list(kh_tables[1].items())
sorted(kh_tables_pos, reverse=True, key=lambda x: x[1])
# Out:
# [('：_COLONCATEGORY', 1296),
#  ('，_COMMACATEGORY', 802),
#  ('。_PERIODCATEGORY', 408),
#  ('判決_VE', 408),
#  ('．_PERIODCATEGORY', 282),
#  ('原文_Na', 259),
#  ('不_D', 237),
#  ('的_DE', 233),
#  ('依_P', 210),
#  ('水桶_Na', 165),
#  ('、_PAUSECATEGORY', 158),
#  ('或_Caa', 153),
#  ('屬_VG', 152),
#  ('］_PARENTHESISCATEGORY', 146),
#  ('［_PARENTHESISCATEGORY', 144),
#  ('是_SHI', 141),
#  ('一_Neu', 129),
#  ('有_V_2', 126),
#  ('故_Cbb', 118),
#  ('之_DE', 116),
#  ('（_PARENTHESISCATEGORY', 113),
#  ('６１_Neu', 111),
#  ('）_PARENTHESISCATEGORY', 110),
#  ('日_Nf', 106),
#  ('新聞_Na', 100),
#  ('高雄_Nc', 94),
#  ('針對_P', 89),
#  ('處_Nf', 83),
#  ('就_D', 81),
#  ('者_Na', 80),
#  ('經_P', 73),
#  ('板友_Na', 72),
#  ('內容_Na', 71),
#  ('文_Na', 70),
#  ('７_Neu', 67),
#  ('處_Nc', 64),
#  ('？_QUESTIONCATEGORY', 62),
#  ('已_D', 62),
#  ('規定_Na', 62),
#  ('引起_VC', 62),
#  ('爭端_Na', 62),
#  ('了_Di', 59),
#  ('請_VF', 59),
#  ('在_P', 57),
#  ('影射_Na', 55),
#  ('特定_A', 54),
#  ('不當_VH', 54),
#  ('族群_Na', 52),
#  ('人_Na', 50),
#  ('以_P', 50),
#  ('徵求_VC', 47),
#  ('歧視_Nv', 47),
#  ('／／ｉ_FW', 46),
#  ('ｉｍｇｕｒ_FW', 46),
#  ('會_D', 46),
#  ('這_Nep', 46),
#  ('我_Nh', 45),
#  ('但_Cbb', 43),
#  ('都_D', 43),
#  ('為_VG', 43),
#  ('無_VJ', 43),
#  ('次_Nf', 42),
#  ('查_VE', 42),
#  ('交換_VC', 41),
#  ('被_P', 40),
#  ('內文_Na', 40),
#  ('也_D', 39),
#  ('文章_Na', 39),
#  ('個_Nf', 39),
#  ('刪_VC', 37),
#  ('禁止_VE', 36),
#  ('應_D', 36),
#  ('於_P', 35),
#  ('可以_D', 34),
#  ('２_Neu', 34),
#  ('再_D', 34),
#  ('篇_Nf', 34),
#  ('並_Cbb', 34),
#  ('違反_VJ', 33),
#  ('交易文_Na', 33),
#  ('警告_VE', 33),
#  ('ｈｔｔｐｓ_FW', 32),
#  ('很_Dfa', 31),
#  ('不足_VH', 31),
#  ('年_Nf', 30),
#  ('退文_VA', 30),
#  ('階_Nf', 30),
#  ('相關_VH', 29),
#  ('程度_Na', 29),
#  ('要_D', 28),
#  ('還_D', 28),
#  ('１_Neu', 27),
#  ('使用_VC', 27),
#  ('其他_Neqa', 27),
#  ('可_D', 27),
#  ('與_Caa', 27),
#  ('自行_D', 27),
#  ('後_Ng', 26),
#  ('二_Neu', 26),
#  ('看板_Na', 26),
#  ('錯誤_Na', 26),
#  ('上_Ncd', 25),
#  ('及_Caa', 25),
#  ('資訊_Na', 25),
#  ('你_Nh', 25),
#  ('未_D', 24),
#  ('好_VH', 24),
#  ('且_Cbb', 24),
#  ('規定_Nc', 24),
#  ('個人_Nh', 24),
#  ('他人_Nh', 24),
#  ('之_Nh', 24),
#  ('同_D', 24),
#  ('行為_Na', 23),
#  ('４_Neu', 23),
#  ('兩_Neu', 23),
#  ('部分_Neqa', 23),
#  ('蟑螂_Na', 23),
#  ('７_Nd', 23),
#  ('說_VE', 22),
#  ('時間_Na', 22),
#  ('推_VC', 22),
#  ('／_FW', 22),
#  ('３_Neu', 22),
#  ('處理_VC', 22),
#  ('上_VC', 22),
#  ('高雄人_Na', 22),
#  ('又_D', 21),
#  ('天_Nf', 21),
#  ('板規_Na', 21),
#  ('內_Ng', 21),
#  ('目前_Nd', 21),
#  ('７１_Neu', 21),
#  ('時_Ng', 20),
#  ('需_D', 20),
#  ('評論_Na', 20),
#  ('嗎_T', 19),
#  ('如果_Cbb', 19),
#  ('了_T', 19),
#  ('５_Neu', 19),
#  ('板主_Na', 19),
#  ('輕軌_Na', 19),
#  ('違_VJ', 19),
#  ('７日_Nd', 19),
#  ('累計為_VG', 19),
#  ('什麼_Nep', 18),
#  ('內_Ncd', 18),
#  ('若_Cbb', 18),
#  ('範圍_Na', 18),
#  ('刪除_VC', 18),
#  ('Ｋａｏｈｓｉｕｎｇ_FW', 18),
#  ('定義_Na', 18),
#  ('３０_Neu', 18),
#  ('～_FW', 18),
#  ('陳其邁_Nb', 18),
#  ('底下_Ncd', 18),
#  ('廣告文_Na', 18),
#  ('罰則_Na', 18),
#  ('等_Cab', 18),
#  ('能_D', 17),
#  ('只_Da', 17),
#  ('真的_D', 17),
#  ('檢舉_VC', 17),
#  ('２２_Neu', 17),
#  ('地點_Na', 17),
#  ('非_D', 17),
#  ('發覺_VK', 17),
#  ('才_Da', 16),
#  ('８_Neu', 16),
#  ('６_Neu', 16),
#  ('知道_VK', 16),
#  ('的_T', 16),
#  ('逾_VJ', 16),
#  ('判決_Nv', 16),
#  ('現在_Nd', 15),
#  ('板_Na', 15),
#  ('換_VC', 15),
#  ('對_P', 15),
#  ('中_Ng', 15),
#  ('查閱_VC', 15),
#  ('玩樂文_Na', 15),
#  ('檢舉_Nv', 15),
#  ('大家_Nh', 14),
#  ('１０_Neu', 14),
#  ('而_Cbb', 14),
#  ('做_VC', 14),
#  ('張貼_VC', 14),
#  ('三_Neu', 14),
#  ('爭議_Na', 14),
#  ('規定處_Nc', 14),
#  ('４％_Neqa', 14),
#  ('種_Nf', 13),
#  ('沒_D', 13),
#  ('過_Di', 13),
#  ('方式_Na', 13),
#  ('大_VH', 13),
#  ('活動_Na', 13),
#  ('直接_VH', 13),
#  ('政治_Na', 13),
#  ('到_P', 13),
#  ('討論_VE', 13),
#  ('看_VC', 13),
#  ('仍_D', 13),
#  ('違規_VA', 13),
#  ('具_VJ', 13),
#  ('宣告_VE', 13),
#  ('該_Nes', 13),
#  ('並_D', 13),
#  ('戰_Na', 13),
#  ('５４_Neu', 13),
#  ('不幸_VH', 13),
#  ('嘲諷_VC', 13),
#  ('越_Na', 13),
#  ('想_VE', 12),
#  ('他_Nh', 12),
#  ('還是_D', 12),
#  ('本_Nes', 12),
#  ('所以_Cbb', 12),
#  ('問題_Na', 12),
#  ('原因_Na', 12),
#  ('發文_Na', 12),
#  ('自己_Nh', 12),
#  ('規範_Na', 12),
#  ('發表_VC', 12),
#  ('１８_Neu', 12),
#  ('僅_Da', 12),
#  ('推文_VA', 12),
#  ('》_PARENTHESISCATEGORY', 12),
#  ('改進_VC', 12),
#  ('無法_D', 12),
#  ('市長_Na', 11),
#  ('小_VH', 11),
#  ('來_D', 11),
#  ('當_VG', 11),
#  ('／／ｉｍｇｕｒ_FW', 11),
#  ('這樣_VH', 11),
#  ('則_D', 11),
#  ('吃_VC', 11),
#  ('每_Nes', 11),
#  ('因_Cbb', 11),
#  ('車輛_Na', 11),
#  ('階段_Na', 11),
#  ('轉錄_VC', 11),
#  ('綠_VH', 11),
#  ('讓_VL', 11),
#  ('政治文_Na', 11),
#  ('愛_VL', 11),
#  ('買賣_VC', 11),
#  ('救濟_Nv', 11),
#  ('同_Nes', 11),
#  ('轉讓_VD', 11),
#  ('《_PARENTHESISCATEGORY', 11),
#  ('帳號_Na', 11),
#  ('確實_D', 11),
#  ('詳述_VC', 11),
#  ('那_Nep', 10),
#  ('一直_D', 10),
#  ('應該_D', 10),
#  ('高雄板_Na', 10),
#  ('狀況_Na', 10),
#  ('沒_VJ', 10),
#  ('看到_VE', 10),
#  ('幾_Neu', 10),
#  ('多_Neqa', 10),
#  ('需要_VK', 10),
#  ('與_P', 10),
#  ('最_Dfa', 10),
#  ('因為_Cbb', 10),
#  ('一樣_VH', 10),
#  ('沒有_VJ', 10),
#  ('在_D', 10),
#  ('參閱_VC', 10),
#  ('說明_VE', 10),
#  ('資料_Na', 10),
#  ('用_P', 10),
#  ('為_P', 10),
#  ('ｐｎｇｈｔｔｐｓ_FW', 10),
#  ('作為_VG', 10),
#  ('字_Na', 10),
#  ('同意_VK', 10),
#  ('判定_VE', 10),
#  ('閒聊_VC', 10),
#  ('併退文_Na', 10),
#  ('啦_T', 10),
#  ('貶抑_Nv', 10),
#  ('邁邁_Nb', 10),
#  ('買_VC', 9),
#  ('贈送_VD', 9),
#  ('堆_Nf', 9),
#  ('找_VC', 9),
#  ('多_VH', 9),
#  ('帶_VC', 9),
#  ('很多_Neqa', 9),
#  ('公告_Na', 9),
#  ('連結_VC', 9),
#  ('完整_VH', 9),
#  ('公開_VHC', 9),
#  ('物品_Na', 9),
#  ('亂_VH', 9),
#  ('啊_T', 9),
#  ('由_P', 9),
#  ('檢舉方_Na', 9),
#  ('怎麼_D', 9),
#  ('覺得_VK', 9),
#  ('禁發_VC', 9),
#  ('Ａ７_FW', 9),
#  ('此_Nep', 9),
#  ('１４_Neu', 9),
#  ('併_VC', 9),
#  ('買賣_Na', 9),
#  ('５２_Neu', 9),
#  ('挑釁_VB', 9),
#  ('言論_Na', 9),
#  ('是否_D', 9),
#  ('引_VC', 9),
#  ('今天_Nd', 8),
#  ('送_VD', 8),
#  ('顏色_Na', 8),
#  ('噴_VC', 8),
#  ('們_Na', 8),
#  ('出現_VH', 8),
#  ('人物_Na', 8),
#  ('其_Nep', 8),
#  ('違_Na', 8),
#  ('算_VG', 8),
#  ('晚上_Nd', 8),
#  ('太_Dfa', 8),
#  ('給_VD', 8),
#  ('最後_Nd', 8),
#  ('標題_Na', 8),
#  ('媒體_Na', 8),
#  ('第二_Neu', 8),
#  ('公司_Nc', 8),
#  ('進行_VC', 8),
#  ('退文_Na', 8),
#  ('四_Neu', 8),
#  ('前_Ng', 8),
#  ('先_D', 8),
#  ('涉及_VK', 8),
#  ('金錢_Na', 8),
#  ('位_Nf', 8),
#  ('把_P', 8),
#  ('真_D', 8),
#  ('列車_Na', 8),
#  ('票券_Na', 8),
#  ('３１_Neu', 8),
#  ('試用_Nv', 8),
#  ('Ａ１０_FW', 8),
#  ('加罰_VC', 8),
#  ('懲處_VC', 8),
#  ('原_A', 8),
#  ('１７_Neu', 8),
#  ('管理_Nv', 8),
#  ('辦法_Na', 8),
#  ('３３_Neu', 8),
#  ('得_D', 8),
#  ('提出_VC', 8),
#  ('條款_Na', 8),
#  ('無_D', 8),
#  ('來_VA', 8),
#  ('藥_Na', 8),
#  ('３９_Neu', 8),
#  ('ｊｐｇ_FW', 7),
#  ('用_VC', 7),
#  ('到_VC', 7),
#  ('吧_T', 7),
#  ('到期_VH', 7),
#  ('可能_D', 7),
#  ('站_Nc', 7),
#  ('家_Nc', 7),
#  ('暖_VH', 7),
#  ('將_D', 7),
#  ('高雄市_Nc', 7),
#  ('００_Neu', 7),
#  ('其實_D', 7),
#  ('怕_VK', 7),
#  ('為主_VI', 7),
#  ('從_P', 7),
#  ('如_Cbb', 7),
#  ('Ａ_FW', 7),
#  ('路段_Na', 7),
#  ('系統_Na', 7),
#  ('全_Neqa', 7),
#  ('更_D', 7),
#  ('交易_Na', 7),
#  ('貼_VC', 7),
#  ('水_Na', 7),
#  ('各_Nes', 7),
#  ('您_Nh', 7),
#  ('八卦板_Na', 7),
#  ('貓咪_Na', 7),
#  ('ｈｔｔｐ_FW', 7),
#  ('交換物_Na', 7),
#  ('５０_Neu', 7),
#  ('但是_Cbb', 7),
#  ('不會_D', 7),
#  ('去_VCL', 7),
#  ('５１_Neu', 7),
#  ('新聞網_Na', 7),
#  ('小心_VK', 7),
#  ('１１_Neu', 7),
#  ('１５_Neu', 7),
#  ('２０_Neu', 7),
#  ('包含_VJ', 7),
#  ('開放_VC', 7),
#  ('折價券_Na', 7),
#  ('３４_Neu', 7),
#  ('４４_Neu', 7),
#  ('以上_Ng', 7),
#  ('達_VJ', 7),
#  ('７２_Neu', 7),
#  ('分身_Nv', 7),
#  ('雖_Cbb', 7),
#  ('５００_Neu', 7),
#  ('高雄點_Na', 7),
#  ('高雄版_Na', 7),
#  ('韓粉_Na', 7),
#  ('升級_VH', 7),
#  ('跟_P', 7),
#  ('０９／１５１９_Nd', 7),
#  ('意味_Na', 7),
#  ('補_VC', 6),
#  ('謝謝_VJ', 6),
#  ('好_Dfa', 6),
#  ('呢_T', 6),
#  ('著_Di', 6),
#  ('或許_D', 6),
#  ('跟_Caa', 6),
#  ('幫_P', 6),
#  ('另外_Da', 6),
#  ('咖哩_Na', 6),
#  ('條_Nf', 6),
#  ('比較_Dfa', 6),
#  ('時期_Na', 6),
#  ('網路_Na', 6),
#  ('認為_VE', 6),
#  ('這些_Neqa', 6),
#  ('任何_Neqa', 6),
#  ('不要_D', 6),
#  ('洗_VC', 6),
#  ('提供_VD', 6),
#  ('警告_Na', 6),
#  ('新_VH', 6),
#  ('達成_VC', 6),
#  ('整合_Nv', 6),
#  ('點_Nf', 6),
#  ('２１_Neu', 6),
#  ('營運_VA', 6),
#  ('民眾_Na', 6),
#  ('工程_Na', 6),
#  ('政府_Na', 6),
#  ('不同_VH', 6),
#  ('查證_VE', 6),
#  ('工作_Na', 6),
#  ('品質_Na', 6),
#  ('工廠_Nc', 6),
#  ('欲_VK', 6),
#  ('張_Nf', 6),
#  ('或是_Caa', 6),
#  ('這麼_D', 6),
#  ('月_Na', 6),
#  ('稱呼_VG', 6),
#  ('罵_VC', 6),
#  ('寫_VC', 6),
#  ('查中_VE', 6),
#  ('週_Nf', 6),
#  ('法律_Na', 6),
#  ('七_Neu', 6),
#  ('視為_VG', 6),
#  ('項_Nf', 6),
#  ('部份_Neqa', 6),
#  ('類_Nf', 6),
#  ('板面_Na', 6),
#  ('交換文_Na', 6),
#  ('３２_Neu', 6),
#  ('上述_Na', 6),
#  ('４１_Neu', 6),
#  ('４３_Neu', 6),
#  ('試用_VC', 6),
#  ('六_Neu', 6),
#  ('受理_VC', 6),
#  ('件_Nf', 6),
#  ('均_D', 6),
#  ('以下_Ncd', 6),
#  ('可能_Na', 6),
#  ('提醒_VE', 6),
#  ('字數_Na', 6),
#  ('改善_VC', 6),
#  ('死_VH', 6),
#  ('噁心_VH', 6),
#  ('改正_VC', 6),
#  ('／／ｔｉｎｙｕｒｌ_FW', 6),
#  ('４０_Neu', 6),
#  ('韓粉_Nb', 6),
#  ('第一_Neu', 6),
#  ('幸福_VH', 6),
#  ('Ｌｅｅｈｅａｖｅｎ_FW', 6),
#  ('ｎｉｃｋｙ５１_FW', 6),
#  ('１０／０１１２_Nd', 6),
#  ('一起_D', 6),
#  ('志工_Na', 6),
#  ('輸血_VB', 6),
#  ('請問_VE', 5),
#  ('地方_Na', 5),
#  ('誰_Nh', 5),
#  ('得_DE', 5),
#  ('附近_Nc', 5),
#  ('面交_VA', 5),
#  ('信_Na', 5),
#  ('以前_Nd', 5),
#  ('去_D', 5),
#  ('蠻_Dfa', 5),
#  ('紀錄_Na', 5),
#  ('皆_D', 5),
#  ('詳細_VH', 5),
#  ('食物_Na', 5),
#  ('６５_Neu', 5),
#  ('名稱_Na', 5),
#  ('店面_Na', 5),
#  ('一些_Neqa', 5),
#  ('難_VH', 5),
#  ('方便_VH', 5),
#  ('和_Caa', 5),
#  ('韓_Nc', 5),
#  ('韓_Nb', 5),
#  ('違者_Na', 5),
#  ('小時_Na', 5),
#  ('作者_Na', 5),
#  ('高市_Nc', 5),
#  ('表示_VE', 5),
#  ('目標_Na', 5),
#  ('禁發_Nv', 5),
#  ('食品_Na', 5),
#  ('日期_Na', 5),
#  ('拿_VC', 5),
#  ('飲料_Na', 5),
#  ('版友_Na', 5),
#  ('某_Nes', 5),
#  ('某些_Neqa', 5),
#  ('中_Ncd', 5),
#  ('多_D', 5),
#  ('結果_Na', 5),
#  ('板務_Na', 5),
#  ('而已_T', 5),
#  ('發生_VJ', 5),
#  ('２９_Neu', 5),
#  ('發言_VA', 5),
#  ('超過_VJ', 5),
#  ('中時_A', 5),
#  ('首犯_Na', 5),
#  ('生活_Na', 5),
#  ('１２_Neu', 5),
#  ('回文_Na', 5),
#  ('判處_VC', 5),
#  ('即_D', 5),
#  ('底_Na', 5),
#  ('置_VC', 5),
#  ('販賣_VD', 5),
#  ('２４_Neu', 5),
#  ('２５_Neu', 5),
#  ('關於_P', 5),
#  ('玩樂_VA', 5),
#  ('情形_Na', 5),
#  ('受_P', 5),
#  ('商業_Na', 5),
#  ('廣告_Na', 5),
#  ('刻意_D', 5),
#  ('理由_Na', 5),
#  ('以上_Ncd', 5),
#  ('６０_Neu', 5),
#  ('判斷_VE', 5),
#  ('查詢_VE', 5),
#  ('所_D', 5),
#  ('３７_Neu', 5),
#  ('智障_VH', 5),
#  ('３８_Neu', 5),
#  ('可_VH', 5),
#  ('４７_Neu', 5),
#  ('記得_VK', 5),
#  ('韓導_Nb', 5),
#  ('跑出來_VA', 5),
#  ('詞彙_Na', 5),
#  ('不可_D', 5),
#  ('５６_Neu', 5),
#  ('推ｑａｚｅｄｃ_VA', 5),
#  ('我們_Nh', 5),
#  ('垃圾_Na', 5),
#  ('察覺_VK', 5),
#  ('功成身退_VH', 5),
#  ('憨粉_Na', 5),
#  ('１０／０９２２_Nd', 5),
#  ('又_Caa', 5),
#  ('肺_Na', 5),
#  ('照片_Na', 4),
#  ('ｊｐｇｈｔｔｐｓ_FW', 4),
#  ('發現_VE', 4),
#  ('沒有_D', 4),
#  ('鄉民_Na', 4),
#  ('味道_Na', 4),
#  ('有效_VH', 4),
#  ('已經_D', 4),
#  ('有沒有_D', 4),
#  ('開始_VL', 4),
#  ('辦_VC', 4),
#  ('好像_D', 4),
#  ('些_Nf', 4),
#  ('過期_VH', 4),
#  ('有關_VJ', 4),
#  ('向_P', 4),
#  ('根本_D', 4),
#  ('的話_Cba', 4),
#  ('簡單_VH', 4),
#  ('ｈｔｔｐｓ_T', 4),
#  ('約_Da', 4),
#  ('八_Neu', 4),
#  ('開始_Ng', 4),
#  ('豬肉_Na', 4),
#  ('相同_VH', 4),
#  ('炸_VC', 4),
#  ('時候_Na', 4),
#  ('講_VE', 4),
#  ('只是_D', 4),
#  ('推文_Na', 4),
#  ('機電_Na', 4),
#  ('階段性_Na', 4),
#  ('如_P', 4),
#  ('新聞文_Na', 4),
#  ('詞_Na', 4),
#  ('捷運局_Nc', 4),
#  ('至_P', 4),
#  ('；_SEMICOLONCATEGORY', 4),
#  ('雖然_Cbb', 4),
#  ('第三_Neu', 4),
#  ('２０２０年_Nd', 4),
#  ('空間_Na', 4),
#  ('前_Nes', 4),
#  ('特別_VH', 4),
#  ('來信_Na', 4),
#  ('處分_Na', 4),
#  ('發文_VA', 4),
#  ('多_Dfa', 4),
#  ('車站_Nc', 4),
#  ('想要_VE', 4),
#  ('喔_T', 4),
#  ('那些_Neqa', 4),
#  ('造成_VG', 4),
#  ('ｐｎｇ_FW', 4),
#  ('上_Nes', 4),
#  ('～_T', 4),
#  ('編號_Na', 4),
#  ('對象_Na', 4),
#  ('性別_Na', 4),
#  ('動物_Na', 4),
#  ('醫院_Nc', 4),
#  ('４６_Neu', 4),
#  ('網軍_Na', 4),
#  ('公關_Na', 4),
#  ('用語_Na', 4),
#  ('不妥_VH', 4),
#  ('含_VC', 4),
#  ('就_P', 4),
#  ('違規_Nv', 4),
#  ('２３_Neu', 4),
#  ('查發文_Na', 4),
#  ('出來_VA', 4),
#  ('上_Ng', 4),
#  ('自由_VH', 4),
#  ('分鐘_Nf', 4),
#  ('點數_Na', 4),
#  ('屬於_VG', 4),
#  ('台灣_Nc', 4),
#  ('非_VG', 4),
#  ('１３_Neu', 4),
#  ('適用_VJ', 4),
#  ('連結_Nv', 4),
#  ('員工_Na', 4),
#  ('買賣區_Nc', 4),
#  ('贈品_Na', 4),
#  ('徵求_Nv', 4),
#  ('徵_VC', 4),
#  ('註明_VE', 4),
#  ('亦_D', 4),
#  ('樂文_Na', 4),
#  ('至多_Da', 4),
#  ('／_PAUSECATEGORY', 4),
#  ('宣傳_VC', 4),
#  ('影響_VC', 4),
#  ('權利_Na', 4),
#  ('閱讀_Nv', 4),
#  ('刪文_Na', 4),
#  ('所有_Neqa', 4),
#  ('附上_VC', 4),
#  ('分類_Na', 4),
#  ('作_VC', 4),
#  ('處份_Na', 4),
#  ('期間_Na', 4),
#  ('合併_VC', 4),
#  ('且_Caa', 4),
#  ('重複_VC', 4),
#  ('３６５０_Neu', 4),
#  ('主帳號_Na', 4),
#  ('確定_VK', 4),
#  ('相似_VH', 4),
#  ('回覆_VD', 4),
#  ('他們_Nh', 4),
#  ('起訴_VC', 4),
#  ('個資_Na', 4),
#  ('明確_VH', 4),
#  ('支持_VC', 4),
#  ('２６_Neu', 4),
#  ('以_Cbb', 4),
#  ('轉_VAC', 4),
#  ('該_D', 4),
#  ('４８_Neu', 4),
#  ('歲_Nf', 4),
#  ('幫忙_VC', 4),
#  ('屬有_VJ', 4),
#  ('打_VC', 4),
#  ('一定_D', 4),
#  ('腦粉_Na', 4),
#  ('丁允恭_Nb', 4),
#  ('爆_VH', 4),
#  ('美_VH', 4),
#  ('豬_Na', 4),
#  ('共_Da', 4),
#  ('ｅｇｇｏｍｅｇａ_FW', 4),
#  ('白_VH', 4),
#  ('生物_Na', 4),
#  ('０９_Neu', 4),
#  ('錢_Na', 4),
#  ('引戰_VA', 4),
#  ('暫不_D', 4),
#  ('貶抑_VC', 4),
#  ('推ＨＡＮＡＸＡＬＩＣＥ_Nv', 4),
#  ('繼續_VF', 4),
#  ('０７_Neu', 4),
#  ('５７_Neu', 4),
#  ('思考_VE', 4),
#  ('搞_VC', 4),
#  ('管_VE', 4),
#  ('噓ｒｅｂｕｉｌｄＭｏｄｅｌ_FW', 4),
#  ('過_VCL', 4),
#  ('給予_VD', 4),
#  ('節錄_VJ', 4),
#  ('像_VG', 4),
#  ('推ａｍｇｎ９９７_VA', 4),
#  ('爽_VH', 4),
#  ('５５_Neu', 4),
#  ('０９／２６１２_FW', 4),
#  ('分享_VJ', 4),
#  ('開_VC', 4),
#  ('冷氣_Na', 4),
#  ('南部_Ncd', 4),
#  ('潑_VC', 4),
#  ('民宅_Na', 4),
#  ('月餅_Na', 4),
#  ('適用_Nv', 4),
#  ('２８_Neu', 4),
#  ('第１５_Neu', 4),
#  ('越_D', 4),
#  ('崩潰_VH', 4),
#  ('蘇光頭_Nb', 4),
#  ('１０／０９２２_Neu', 4),
#  ('卵_Na', 4),
#  ('廢物_Na', 4),
#  ('報名_VA', 4),
#  ('感謝_VK', 3),
#  ('氣球_Na', 3),
#  ('歌_Na', 3),
#  ('小朋友_Na', 3),
#  ('溫馨_VH', 3),
#  ('非常_Dfa', 3),
#  ('香水_Na', 3),
#  ('本_D', 3),
#  ('總_D', 3),
#  ('價值_Na', 3),
#  ('試_VF', 3),
#  ('ｃｏｍ／_FW', 3),
#  ('期限_Na', 3),
#  ('國小_Nc', 3),
#  ('要_VC', 3),
#  ('樹_Na', 3),
#  ('蘋果_Na', 3),
#  ('大概_D', 3),
#  ('外_Ncd', 3),
#  ('配合_VC', 3),
#  ('心得_Na', 3),
#  ('像是_SHI', 3),
#  ('常_D', 3),
#  ('路_Na', 3),
#  ('這邊_Ncd', 3),
#  ('左右_Ng', 3),
#  ('變成_VG', 3),
#  ('元_Nf', 3),
#  ('雙主菜_Na', 3),
#  ('加_VC', 3),
#  ('咖哩飯_Na', 3),
#  ('湯汁_Na', 3),
#  ('不錯_VH', 3),
#  ('財_Na', 3),
#  ('懂_VK', 3),
#  ('酸_VH', 3),
#  ('事_Na', 3),
#  ('ｓｉｍｏｎｊｅｎ_FW', 3),
#  ('利用_VC', 3),
#  ('長_VH', 3),
#  ('網址_Na', 3),
#  ('網友_Na', 3),
#  ('／／ｗｗｗ_FW', 3),
#  ('ｃｏｍ_FW', 3),
#  ('車_Na', 3),
#  ('上線_VA', 3),
#  ('來源_Na', 3),
#  ('中央社_Nc', 3),
#  ('更新_VC', 3),
#  ('記者_Na', 3),
#  ('明天_Nd', 3),
#  ('測試_Na', 3),
#  ('作業_Na', 3),
#  ('確認_VE', 3),
#  ('代表_Na', 3),
#  ('後續_A', 3),
#  ('行_VA', 3),
#  ('線_Na', 3),
#  ('城市_Na', 3),
#  ('環境_Na', 3),
#  ('則_Nf', 3),
#  ('自刪_VC', 3),
#  ('注意_VK', 3),
#  ('楠梓_Nc', 3),
#  ('烘碗機_Na', 3),
#  ('聯絡_Nv', 3),
#  ('收取_VC', 3),
#  ('眼鏡_Na', 3),
#  ('到_VCL', 3),
#  ('慘_VH', 3),
#  ('拜託_VC', 3),
#  ('洽中_VC', 3),
#  ('健身_Nv', 3),
#  ('杯_Nf', 3),
#  ('皮革_Na', 3),
#  ('至於_P', 3),
#  ('情況_Na', 3),
#  ('平衡_VHC', 3),
#  ('一下_Nd', 3),
#  ('首先_D', 3),
#  ('貼文_Na', 3),
#  ('何_Nes', 3),
#  ('標籤_Na', 3),
#  ('敢_VL', 3),
#  ('當年_Nd', 3),
#  ('實在_D', 3),
#  ('那_Dk', 3),
#  ('物資_Na', 3),
#  ('告知_VE', 3),
#  ('救援_Nv', 3),
#  ('隻_Nf', 3),
#  ('正常_VH', 3),
#  ('今_Nd', 3),
#  ('平穩_VH', 3),
#  ('緊急_VH', 3),
#  ('１０／３１_Nd', 3),
#  ('１１／０１２３_Nd', 3),
#  ('主_Na', 3),
#  ('她_Nh', 3),
#  ('侮辱_VC', 3),
#  ('對於_P', 3),
#  ('柯文哲_Nb', 3),
#  ('提到_VE', 3),
#  ('歷史_Na', 3),
#  ('唷_FW', 3),
#  ('疏失_Na', 3),
#  ('報導_Na', 3),
#  ('公告_VE', 3),
#  ('給_P', 3),
#  ('原來_D', 3),
#  ('太多_VH', 3),
#  ('最近_Nd', 3),
#  ('以下_Ng', 3),
#  ('鳳山_Nc', 3),
#  ('宣告_Na', 3),
#  ('規則_Na', 3),
#  ('娛樂_Na', 3),
#  ('事件_Na', 3),
#  ('無關_VH', 3),
#  ('中華民國_Nc', 3),
#  ('信件_Na', 3),
#  ('１／２１_Nd', 3),
#  ('１６_Neu', 3),
#  ('勿_D', 3),
#  ('情節_Na', 3),
#  ('特殊_VH', 3),
#  ('需求_Na', 3),
#  ('票據_Na', 3),
#  ('票根_Na', 3),
#  ('簽名檔_Na', 3),
#  ('形式_Na', 3),
#  ('發_VD', 3),
#  ('例如_P', 3),
#  ('間隔_VJ', 3),
#  ('１／１１_Nd', 3),
#  ('人文_Na', 3),
#  ('玩_VC', 3),
#  ('課程_Na', 3),
#  ('具_Nf', 3),
#  ('要求_VF', 3),
#  ('惡意_D', 3),
#  ('版_Na', 3),
#  ('影射_VJ', 3),
#  ('攻擊_VC', 3),
#  ('註_Na', 3),
#  ('公告文_Na', 3),
#  ('退_VA', 3),
#  ('新增_VJ', 3),
#  ('臨時_Nd', 3),
#  ('任意_VH', 3),
#  ('地區_Nc', 3),
#  ('申請_VF', 3),
#  ('許可_VE', 3),
#  ('得以_D', 3),
#  ('符合_VJ', 3),
#  ('必要_VH', 3),
#  ('退文_Nv', 3),
#  ('申訴_VE', 3),
#  ('明知_VK', 3),
#  ('６１４_Neu', 3),
#  ('處_VC', 3),
#  ('論_VC', 3),
#  ('案件_Na', 3),
#  ('７５_Neu', 3),
#  ('不滿_VK', 3),
#  ('處理_Nv', 3),
#  ('程序_Na', 3),
#  ('加倍_VH', 3),
#  ('尚未_D', 3),
#  ('移除_VC', 3),
#  ('修正_VC', 3),
#  ('八卦版_Na', 3),
#  ('造謠_Na', 3),
#  ('私人_Nh', 3),
#  ('怎麼_VH', 3),
#  ('第四_Neu', 3),
#  ('說明_Na', 3),
#  ('符號_Na', 3),
#  ('０９／０６０７_Neu', 3),
#  ('文具_Na', 3),
#  ('詢問_VE', 3),
#  ('１９_Neu', 3),
#  ('黑_VH', 3),
#  ('市府_Nc', 3),
#  ('０～１９９_Neu', 3),
#  ('明白_VK', 3),
#  ('臭_VH', 3),
#  ('別_D', 3),
#  ('０９／１００９_Nd', 3),
#  ('哪_Nep', 3),
#  ('推Ｓｕｂｌｉｍｉｎａｌ_VA', 3),
#  ('ＸＥ０９／１０１１_Nd', 3),
#  ('０９／１０１５_Nd', 3),
#  ('昆蟲類_Na', 3),
#  ('昆蟲_Na', 3),
#  ('反對_VE', 3),
#  ('４２_Neu', 3),
#  ('高雄板引_Na', 3),
#  ('３６_Neu', 3),
#  ('０９／１０２２_Neu', 3),
#  ('原由_Na', 3),
#  ('糞_Na', 3),
#  ('０９／１１１４_Nd', 3),
#  ('９／２７_Nd', 3),
#  ('租賃_Nv', 3),
#  ('登入_VCL', 3),
#  ('．ｃｏｍ／ｙ６９ｄｗｊａｎ_FW', 3),
#  ('解_VC', 3),
#  ('領_VC', 3),
#  ('０９／１１１３_FW', 3),
#  ('騎車_VA', 3),
#  ('粉_Na', 3),
#  ('事實_Na', 3),
#  ('５６ｓａｎｗａｎ_FW', 3),
#  ('卻_D', 3),
#  ('知_VK', 3),
#  ('存在_VA', 3),
#  ('騙_VC', 3),
#  ('乙烯_Na', 3),
#  ('便當_Na', 3),
#  ('選民_Na', 3),
#  ('年_Na', 3),
#  ('增_VJ', 3),
#  ('０９／１２０６_Nd', 3),
#  ('ｑａｚｅｄｃ_FW', 3),
#  ('初犯_Na', 3),
#  ('換出_VC', 3),
#  ('０３_Neu', 3),
#  ('區_Nc', 3),
#  ('規矩_Na', 3),
#  ('ｓｉｇｎｏｒｒ_FW', 3),
#  ('０９／１６１９_Nd', 3),
#  ('爸爸_Na', 3),
#  ('爆_VC', 3),
#  ...]

# %% [markdown]
# #### 4.3 高雄版詞意頻表

# %%
# sorting sense frequency tables
kh_tables_sense = list(kh_tables[2].items())
sorted(kh_tables_sense, reverse=True, key=lambda x: x[1])
# Out:
# [('：__', 1296),
#  ('，__', 802),
#  ('。__', 408),
#  ('判決__', 408),
#  ('．__', 282),
#  ('原文_04060101_原來的文本。', 259),
#  ('不_05010901_表疑問的語氣，置於句末。', 234),
#  ('水桶__', 165),
#  ('、__', 158),
#  ('屬__', 152),
#  ('］__', 146),
#  ('［__', 144),
#  ('（__', 113),
#  ('６１__', 111),
#  ('）__', 110),
#  ('日_03036209_計算時間的單位。一日為二十四小時。', 106),
#  ('依_04018504_引介遵循的原則。', 98),
#  ('高雄_06047401_位於臺灣南部，介於臺東縣、屏東縣、臺南縣之間的地區。', 91),
#  ('７__', 91),
#  ('或_04001201_連接語意相似的詞組或子句，表選擇關係或並列關係。', 90),
#  ('針對_04017001_引介事件所涉及的特定對象。', 89),
#  ('的_07023402_表領屬關係，用於修飾語和中心語間。', 88),
#  ('規定_06678002_要求他人在進行特定事件時必須遵守的內容。', 86),
#  ('處_03007402_計算部位、地點的單位。', 83),
#  ('故_03015807_表帶有明確意圖做事。', 82),
#  ('者_06641401_具有前述身份或進行前述行為的人或團體。', 78),
#  ('之_04090401_表一般的修飾關係，用於修飾語和中心語間。', 76),
#  ('經_05002105_引介事件進行的過程或方法。', 73),
#  ('板友__', 72),
#  ('內容_06773301_特定事物內部所包含的實質對象。', 70),
#  ('？__', 62),
#  ('已_06668401_表後述事件在說話之前發生或完成。', 62),
#  ('引起_06772201_因使特定對象注意而導致後述結果。', 62),
#  ('爭端__', 62),
#  ('文_05156301_獨立而首尾完整的成篇文字。', 60),
#  ('影射__', 59),
#  ('依_04018505_引介判斷的標準或條件。', 58),
#  ('請_06532302_用客氣的語氣提出後述要求。', 57),
#  ('特定__', 54),
#  ('不當__', 54),
#  ('徵求__', 52),
#  ('族群_06691401_人類由相同語言、種族、地域等文化因素所構成的群體。', 52),
#  ('是_07023505_表後述動作的受事者是前述對象。', 50),
#  ('的_07023408_列舉相類似的事物。', 50),
#  ('或_04001203_表猜測。', 50),
#  ('處_03007401_特定對象所在的地方。', 48),
#  ('新聞_06707702_報導新聞的節目。', 47),
#  ('歧視__', 47),
#  ('／／ｉ__', 46),
#  ('ｉｍｇｕｒ__', 46),
#  ('是_09250001_形容正確的或處理特定事件的作法適當。', 46),
#  ('有_04013807_表肯定事件的發生。', 45),
#  ('有_04013803_後述對象存在。', 45),
#  ('交換__', 43),
#  ('依_04018506_引介特定的觀點。', 43),
#  ('是_09250101_前述事物的代稱。', 42),
#  ('的_07023401_表一般的修飾關係，用於修飾語和中心語間。', 42),
#  ('退文__', 41),
#  ('查_05008402_為了解事件而收集資料。', 41),
#  ('會_04143405_表在通常狀況下，有可能實現。', 40),
#  ('人_05231101_軀幹直立，用雙腳行走的高等動物，具備思考能力，有語言文字，能進行社交活動。', 40),
#  ('被_04011801_引介施事者。', 40),
#  ('內文__', 40),
#  ('次_05048202_計算事件發生的次數的單位。', 39),
#  ('這_05223501_根據說話者說話時所處的時空而言，指稱比較近的後述對象。', 39),
#  ('ｈｔｔｐｓ__', 38),
#  ('了_04005202_表示變化或出現新的情況，置於句末或句中停頓處。', 38),
#  ('之_04090402_表領屬關係，用於修飾語和中心語間。', 38),
#  ('故_03015808_連接因上述原因而得到的後述結果或結論。', 38),
#  ('在_04015702_引介處所。', 37),
#  ('刪_09020201_在特定範圍中去除特定項目或內容。', 37),
#  ('禁止_05050501_制止、不允許作特定動作或行為。', 36),
#  ('應_06722301_表按照道理必須做後述事件。', 36),
#  ('但_06751601_表連接句子的轉折語氣，用來引出命題和前文相對的句子。', 35),
#  ('一_05224201_數目字。整數，最小的正整數。', 34),
#  ('２__', 34),
#  ('篇_03032102_計算文章的單位。', 34),
#  ('一_06727301_事物的全體。', 33),
#  ('檢舉__', 33),
#  ('並_04159701_連接兩對等句子，表示進一層關係。', 33),
#  ('違反_06600101_不遵守後述規定或不履行承諾。', 33),
#  ('交易文__', 33),
#  ('警告__', 33),
#  ('很_05172901_表超過平常的程度。', 31),
#  ('不足__', 31),
#  ('階_07071507_計算音程的單位。', 30),
#  ('一_05224202_序數。順序排在第一。', 30),
#  ('我_05238701_代指說話者。', 29),
#  ('就_05198301_表前述事件為後述事件的充分條件，表示在該條件或情況下自然發展。', 29),
#  ('再_06774402_表接連發生事件中的後述發生事件。', 29),
#  ('年_05229303_計算時間的單位，一年有十二個月。', 29),
#  ('相關__', 29),
#  ('有_04013802_斷定特定對象有後述性質。', 28),
#  ('１__', 28),
#  ('其他_03032801_另外的。', 27),
#  ('違__', 27),
#  ('新聞_06707703_新發生的，大多數人還不知道的消息。', 27),
#  ('／__', 27),
#  ('自行_06606401_表主事者獨自進行後述事件。', 27),
#  ('為_04012003_前述對象連接的是後述對象，表兩者指涉相同。', 26),
#  ('二_05124702_序數。順序排在第二。', 26),
#  ('與_04001301_連接並列的詞組，表做連接的事件同時成立。', 26),
#  ('看板__', 26),
#  ('錯誤__', 26),
#  ('及_03020201_連接並列的詞組，表做連接的事件同時成立。', 25),
#  ('資訊_06681501_特定資料或訊息。', 25),
#  ('了_04005201_時態標記。表事件的結束或完整性，置於動詞後。', 24),
#  ('後_03018210_晚於特定參考時間點或事件。', 24),
#  ('未_04001801_表否定事件的發生或狀態。', 24),
#  ('新聞_06707701_大眾傳播媒體中對特定事件的報導和傳播。', 24),
#  ('他人_04089201_代指說話者或聽話者以外的人。', 24),
#  ('上_04081314_事件的發生在前述事物的範圍內。', 23),
#  ('行為_06666101_具體表現出的外在舉止動作。', 23),
#  ('４__', 23),
#  ('～__', 23),
#  ('蟑螂__', 23),
#  ('使用_06722405_比喻選擇後述有系統性的態度或方式。', 22),
#  ('文章_06767802_特定事件中隱藏在其他對象中的涵義。', 22),
#  ('可以_06715202_表後述事件為聽話者可以選擇自己進行的事件之一。', 22),
#  ('３__', 22),
#  ('無_06586502_後述對象不存在。', 22),
#  ('處理_06586102_使動物失去生命。', 22),
#  ('評論__', 22),
#  ('部分_03003701_整體中可區分的組成單位。', 22),
#  ('高雄人__', 22),
#  ('天_05225405_計算時間的單位。一天為二十四小時。', 21),
#  ('的_07023407_表肯定或加強的語氣。', 21),
#  ('板規__', 21),
#  ('無_06586501_不擁有後述對象。', 21),
#  ('且_04000602_連接兩對等句子，表示進一層關係。', 21),
#  ('兩_06051201_數目字。整數，為一加一的和。', 21),
#  ('目前_07023601_說話者所在的時間參考點。', 21),
#  ('７１__', 21),
#  ('之_05001302_沒有固定的指涉，虛指。', 21),
#  ('也_06774601_表所描述的對象屬於同一類。', 20),
#  ('需_04037301_前述事件因特定理由而仰賴後述對象。', 20),
#  ('非_04038004_表一定，排除其他可能性。', 20),
#  ('買賣__', 20),
#  ('同_04016306_引介比較的對象。', 20),
#  ('上_04081332_老師在特定學校系統教授特定課程。', 20),
#  ('時_03038501_事件發生的時間。', 19),
#  ('如果_05234101_連接假設條件。', 19),
#  ('就_05198313_表加強說話者對陳述內容的肯定。', 19),
#  ('５__', 19),
#  ('板主__', 19),
#  ('在_04015710_表後述動作進行中或持續中。', 19),
#  ('輕軌__', 19),
#  ('定義__', 19),
#  ('３０__', 19),
#  ('７日__', 19),
#  ('累計為__', 19),
#  ('程度_06610902_特定事件將要發生變化的階段。', 19),
#  ('只_06723902_表限定範圍。', 18),
#  ('若_06053401_連接假設條件。', 18),
#  ('以_04014106_引介處置的對象。', 18),
#  ('２２__', 18),
#  ('刪除__', 18),
#  ('推文__', 18),
#  ('Ｋａｏｈｓｉｕｎｇ__', 18),
#  ('內_04086402_在前述的時間範圍內。', 18),
#  ('陳其邁__', 18),
#  ('底下__', 18),
#  ('廣告文__', 18),
#  ('罰則__', 18),
#  ('都_05196902_表超過預設條件。', 17),
#  ('的_07023404_表前述對象是離合動賓動詞的賓語。', 17),
#  ('文章_06767801_獨立而首尾完整的成篇文字。', 17),
#  ('討論__', 17),
#  ('以_04014101_引介事件所憑藉的方法或工具。', 17),
#  ('地點_05202301_地理上的位置。', 17),
#  ('違規__', 17),
#  ('查閱__', 17),
#  ('宣告__', 17),
#  ('規定處__', 17),
#  ('了_05003602_時態標記。表前述對象對該事件或動作有實現的能力。', 16),
#  ('能_04142902_表具備達到後述事件成立的條件。', 16),
#  ('要_06636905_表按照道理必須做後述事件。', 16),
#  ('８__', 16),
#  ('６__', 16),
#  ('內_04086401_在前述對象所包含的空間範圍。', 16),
#  ('我_05238702_代指說話者所擁有的。', 16),
#  ('範圍_06636602_比喻特定對象所涉及到的所有相關事物。', 16),
#  ('於_04015602_引介處所。', 16),
#  ('張貼__', 16),
#  ('你_05238602_代指單數的聽話者所擁有的。', 16),
#  ('發文__', 16),
#  ('個人_04089603_單獨一人。', 16),
#  ('判決_05190204_裁判對比賽過程或結果做出的決定。', 16),
#  ('現在_07023801_說話者所在的時間參考點。', 15),
#  ('１０__', 15),
#  ('可_06560502_表後述事件為聽話者可以選擇自己進行的事件之一。', 15),
#  ('還_05002703_表前述範圍之外有所補充。', 15),
#  ('玩樂文__', 15),
#  ('救濟__', 15),
#  ('等_04001108_表列舉清單結束。', 15),
#  ('禁發__', 14),
#  ('的_07023406_表在前述情況下。', 14),
#  ('中_04004618_在事件的過程中。', 14),
#  ('試用__', 14),
#  ('該_05212501_指前述談話內容中已提過的對象。', 14),
#  ('並_04159702_表加強否定的語氣，通常與預設知識相反。', 14),
#  ('於_04015607_引介事件的來源。', 14),
#  ('爭議__', 14),
#  ('４％__', 14),
#  ('貶抑__', 14),
#  ('嘲諷__', 14),
#  ('大家_05196701_代指一定範圍內所有的人。', 13),
#  ('板_07057608_網路上的討論區，通常劃分不同的主題，讓使用者表達意見，進行討論。', 13),
#  ('沒_03028105_否定事件的發生。', 13),
#  ('方式_06774301_做事的步驟或技巧。', 13),
#  ('說_05212401_以口語媒介傳達訊息。', 13),
#  ('都_05196901_表全部。', 13),
#  ('活動_06760004_人類經過規劃所進行的各項行動。', 13),
#  ('個_07011204_計算特定對象大約的數量的單位。', 13),
#  ('一_06727305_表不正式做特定動作。', 13),
#  ('都_05196903_表後述事件在說話之前發生或完成。', 13),
#  ('連結__', 13),
#  ('規範__', 13),
#  ('仍_06751101_表動作或情況持續不變。', 13),
#  ('發覺_05050901_察覺到新的狀態。', 13),
#  ('韓粉__', 13),
#  ('５４__', 13),
#  ('不幸__', 13),
#  ('逾_05119902_超過後述限定界限。', 13),
#  ('越_05240201_「越南」的縮寫。', 13),
#  ('種_06516609_計算事物類別的單位。', 12),
#  ('可以_06715201_表前述對象具有進行後述事件的條件。', 12),
#  ('好_04157701_形容對特定對象的評價是正面的。', 12),
#  ('轉錄__', 12),
#  ('或_04001202_連接列舉事項。', 12),
#  ('原因_06531201_造成特定結果或引起另一件事情發生的條件。', 12),
#  ('一_06727302_全體中的所有個體單位，強調各個個體都適用。', 12),
#  ('具_05071901_斷定特定對象有後述性質。', 12),
#  ('發表_06747401_公開出版作品或宣讀文字。', 12),
#  ('１８__', 12),
#  ('》__', 12),
#  ('改進__', 12),
#  ('無法_04162301_表沒有做後述事件的能力。', 12),
#  ('嗎_07024301_表對前述命題疑問的語氣詞。', 11),
#  ('過_05206001_時態標記。表事件在參考時點前曾經發生。', 11),
#  ('高雄板__', 11),
#  ('真的_05052202_表與事實一樣。', 11),
#  ('市長__', 11),
#  ('時間_06560102_時點。', 11),
#  ('當_04013901_前述對象的工作或身份是後述對象。', 11),
#  ('本_07023718_指時空上距離說話者較近的後述對象。', 11),
#  ('／／ｉｍｇｕｒ__', 11),
#  ('這樣__', 11),
#  ('因_04018803_連接原因或理由。', 11),
#  ('車輛__', 11),
#  ('階段_06530001_特定事件變化或發展時依照時序分成多個段落的其中一部分。', 11),
#  ('時間_06560103_時間的一個段落。', 11),
#  ('政治文__', 11),
#  ('轉讓__', 11),
#  ('僅_04034302_表限定範圍。', 11),
#  ('《__', 11),
#  ('挑釁__', 11),
#  ('帳號__', 11),
#  ('確實_04036402_表說話者對事件真實性的肯定。', 11),
#  ('詳述__', 11),
#  ('贈送__', 10),
#  ('應該_07024101_表按照道理必須做後述事件。', 10),
#  ('什麼_05224701_表示對描述對象的疑問。', 10),
#  ('看到_06667501_用眼睛察覺到，強調動作的結果。', 10),
#  ('需要__', 10),
#  ('嗎_07024302_表徵詢對方意願的疑問語氣。', 10),
#  ('最_05100901_表比較之後屬性超過所有其他同類的對象。', 10),
#  ('因為_05234001_連接原因或理由。', 10),
#  ('一樣_06586601_形容沒有差別的。', 10),
#  ('吃_05227001_使物體經過口中吞入體內。', 10),
#  ('的_07023403_表使謂語具名詞性，用於主語和謂語間。', 10),
#  ('參閱__', 10),
#  ('前_03033712_早於特定參考時間點或事件。', 10),
#  ('就_05198311_表前述情況已滿足主觀的最低條件。', 10),
#  ('資料_06774001_可供參考的書面內容。', 10),
#  ('分身__', 10),
#  ('ｐｎｇｈｔｔｐｓ__', 10),
#  ('作為_06556902_把兩個描述對象認定為相同或具有相同功能。', 10),
#  ('字_06584502_中文書面書寫的最小單位。', 10),
#  ('１４__', 10),
#  ('同意__', 10),
#  ('同_04016303_指稱後述的對象相同。', 10),
#  ('判定__', 10),
#  ('程度_06610901_特定事件的衡量標準。', 10),
#  ('閒聊__', 10),
#  ('併退文__', 10),
#  ('邁邁__', 10),
#  ('１０／０９２２__', 10),
#  ('ｊｐｇ__', 9),
#  ('買_06773201_付出金錢以取得物品的所有權。', 9),
#  ('知道_05233904_具備後述能力。', 9),
#  ('多_03010607_勝過標準的程度。', 9),
#  ('１１__', 9),
#  ('所以_06751402_在結果句中標示主題，後接解釋原因，表因果關係。', 9),
#  ('公告_04111602_對大眾宣布的公文。', 9),
#  ('完整__', 9),
#  ('直接_06772505_形容比喻不必透過媒介就能產生關連的。', 9),
#  ('處_03007403_比喻特定的抽象地方。', 9),
#  ('公開__', 9),
#  ('可_06560501_表前述對象具有進行後述事件的條件。', 9),
#  ('物品__', 9),
#  ('做_06664306_做，取代整個事件。', 9),
#  ('用_04017407_引介事件所憑藉的方法或工具。', 9),
#  ('檢舉方__', 9),
#  ('Ａ７__', 9),
#  ('三_05224302_序數，順序排在第三。', 9),
#  ('以_04014104_引介判斷的標準或條件。', 9),
#  ('併__', 9),
#  ('管理_06721604_研究管理的知識。', 9),
#  ('５２__', 9),
#  ('言論__', 9),
#  ('是否_03039101_表正反問句的疑問詞。', 9),
#  ('看_04004501_用眼睛察覺。', 9),
#  ('他_05238501_代指自己和對方以外的第三人。', 8),
#  ('才_06726002_表因前述事情而導致後述事件。', 8),
#  ('還是_04000501_表預期會改變的情況維持不變。', 8),
#  ('幾_09251201_表示兩個以上，但不確定的數量。', 8),
#  ('小_05227106_形容年紀小的。', 8),
#  ('出現__', 8),
#  ('人物_06636001_具有前述特質且具有代表性的人。', 8),
#  ('與_04001302_引介關聯的對象。', 8),
#  ('將_04011601_表預期後述事件會在很短的時間內發生。', 8),
#  ('晚上_05235901_太陽下山後到太陽出來前的時間。', 8),
#  ('太_05196601_表程度極高。', 8),
#  ('很多_05124601_數量大或種類多。', 8),
#  ('來_04086508_表前述對象進行後述事件。', 8),
#  ('每_03028201_全體中的所有個體單位，強調各個個體都適用。', 8),
#  ('韓導__', 8),
#  ('沒_03028101_不擁有後述對象。', 8),
#  ('如_03036504_連接假設條件。', 8),
#  ('標題__', 8),
#  ('整合__', 8),
#  ('第二__', 8),
#  ('公司_06681901_依法定程序成立，以營利為目的並具有法人資格的機構。', 8),
#  ('進行_06695201_朝特定方向移動。', 8),
#  ('個_07011201_計算能獨立成件的具體對象的單位。', 8),
#  ('要_06636907_表預期後述事件會在很短的時間內發生。', 8),
#  ('先_06532401_表時間或順序在前的。', 8),
#  ('涉及_03037701_關聯到。', 8),
#  ('金錢_06520901_通指貨幣。', 8),
#  ('ｈｔｔｐ__', 8),
#  ('位_06587307_計算特定人物的單位。', 8),
#  ('對_04017507_引介受事者。', 8),
#  ('列車__', 8),
#  ('票券__', 8),
#  ('３１__', 8),
#  ('Ａ１０__', 8),
#  ('加罰__', 8),
#  ('懲處__', 8),
#  ('高雄點__', 8),
#  ('由_04011909_引介後述事件施事者。', 8),
#  ('適用__', 8),
#  ('１７__', 8),
#  ('推_05230704_比喻拒絕接受後述對象。', 8),
#  ('辦法_06531002_進行特定事件所應遵守的法則。', 8),
#  ('３３__', 8),
#  ('條款__', 8),
#  ('無_06586504_連接任意的條件，雖然條件不同但結果相同。', 8),
#  ('３９__', 8),
#  ('今天_07024601_說話者所在的時間參考點的那一天。', 7),
#  ('顏色_06716102_多種的顏色。', 7),
#  ('那_04020101_根據說話者說話時所處的時空而言，指稱比較遠的後述對象。', 7),
#  ('堆_04083205_數量相當多的後述對象。', 7),
#  ('到期_05062601_形容到達約定或可以使用的期限。', 7),
#  ('可能_06745901_表會成為事實或是事實。', 7),
#  ('政治_06047501_與政府組織或權力運作相關的社會活動。', 7),
#  ('咖哩__', 7),
#  ('高雄市_06048301_位於臺灣南部，為臺灣第二個直轄市。', 7),
#  ('００__', 7),
#  ('其實_05100501_表事件的實際情況。', 7),
#  ('為主_03044601_在重要性上位居首要。', 7),
#  ('沒有_04001901_不擁有後述對象。', 7),
#  ('就_05198312_表後述命題和前文相對，具有轉折的語氣。', 7),
#  ('個_07011202_計算特定抽象名詞的單位。', 7),
#  ('Ａ__', 7),
#  ('路段__', 7),
#  ('交易__', 7),
#  ('綠_05223702_形容顏色為綠的，像草或樹葉的。', 7),
#  ('就_05198307_表強調說話者已知事實。', 7),
#  ('個_07011203_計算時間的單位。', 7),
#  ('為_04012001_做，取代整個事件。', 7),
#  ('最後_07024701_時序或次序排在所有其他同類之後的位置。', 7),
#  ('各_04033901_指全體中的所有個體單位，強調個體的特性。', 7),
#  ('您_04090801_代指單數的聽話者。', 7),
#  ('八卦板__', 7),
#  ('換_06607001_以交換的方式得到特定對象。', 7),
#  ('你_05238601_代指單數的聽話者。', 7),
#  ('但_06751602_表對後述對象的評價比預期低。', 7),
#  ('貓咪__', 7),
#  ('交換物__', 7),
#  ('５０__', 7),
#  ('但是_06614201_表連接句子的轉折語氣，用來引出命題和前文相對的句子。', 7),
#  ('不會_06695101_提醒語。用於表達對於他人的請求樂意幫忙，不覺得麻煩。', 7),
#  ('５１__', 7),
#  ('中時__', 7),
#  ('新聞網__', 7),
#  ('小心__', 7),
#  ('１５__', 7),
#  ('個人_04089602_代指當事人。', 7),
#  ('２０__', 7),
#  ('判處__', 7),
#  ('包含_06549302_後述對象被包括在前述範圍裡。', 7),
#  ('折價券__', 7),
#  ('３４__', 7),
#  ('４４__', 7),
#  ('多_03010602_數量大於一。', 7),
#  ('７２__', 7),
#  ('雖_04030401_連接不影響後述事實的條件，隱含讓步。', 7),
#  ('提醒__', 7),
#  ('５００__', 7),
#  ('來_04086501_向參考點的位置移動或到達參考點的位置。', 7),
#  ('高雄版__', 7),
#  ('處_03007404_機關中的組織單位。', 7),
#  ('０９／１５１９__', 7),
#  ('意味_03051002_含義或意境。', 7),
#  ('０９／２６１２__', 7),
#  ('１０／０１１２__', 7),
#  ('謝謝__', 6),
#  ('好_04157710_表說話者主觀評價程度高，帶有誇張語氣或情感。', 6),
#  ('又_04000901_連接兩對等詞組，表兩種狀況同時存在。', 6),
#  ('或許_04037401_表猜測。', 6),
#  ('面交__', 6),
#  ('找_06558901_搜尋需要的特定對象。', 6),
#  ('去_06559205_表前述對象進行後述事件。', 6),
#  ('幫_04016702_引介動作的受益者。', 6),
#  ('人_05231105_自己以外的人。', 6),
#  ('推_05230707_比喻贊成他人所發表的言論。', 6),
#  ('比較_04148502_表與其他同類對象做對照比較時，程度上高一點。', 6),
#  ('時期_06527601_一段時間。', 6),
#  ('認為_05201101_引述或陳述前述對象的認知。', 6),
#  ('這些_05076801_離說話者或參考點較近的多個對象。', 6),
#  ('任何_03035901_同類事物中不確定的數量。', 6),
#  ('對_04017506_引介事件所涉及的對象或範圍。', 6),
#  ('提供__', 6),
#  ('達成__', 6),
#  ('２１__', 6),
#  ('營運_06573703_比喻長期規劃投入特定事件，使其達到自己的理想。', 6),
#  ('民眾_06666701_自然形成的社會群體，具有某些共同屬性。', 6),
#  ('政府_06668001_執行國家權力的機關。', 6),
#  ('不同__', 6),
#  ('查證__', 6),
#  ('品質_06773101_特定對象的性質的優劣程度。', 6),
#  ('更_09250802_表程度加深。', 6),
#  ('一直_06640103_表狀態從過去持續到參考時點，強調其狀態沒有改變過。', 6),
#  ('狀況_06771901_前述事件呈現出來的狀態。', 6),
#  ('欲_06678502_心中存有完成後述事件的願望。', 6),
#  ('大_05227207_形容有前述年紀的。', 6),
#  ('看_04004504_透過視覺來理解或欣賞。', 6),
#  ('張_03055301_計算平面物體的單位。', 6),
#  ('文_05156307_文言。', 6),
#  ('多_03010605_表程度加強或頻率增加。', 6),
#  ('或是_03019801_連接語意相似的詞組或子句，表選擇關係或並列關係。', 6),
#  ('這麼_06530501_表言談中已確立的事件程度。', 6),
#  ('真_05100413_表對客觀情況的真實性給予評價。', 6),
#  ('月_05229205_時段的單位。', 6),
#  ('問題_06560401_發問的內容。', 6),
#  ('發生__', 6),
#  ('這_05223503_代指上文中已提過的對象。', 6),
#  ('而_04000803_連接前述原因和後述結果的詞組，用以表示因果關係。', 6),
#  ('覺得_05209202_產生後述情感或態度。', 6),
#  ('罵_06763901_以粗話惡語侮辱人。', 6),
#  ('則_06778703_表言談中用於標記語氣的轉折。', 6),
#  ('查中__', 6),
#  ('週_04084501_時間的單位，一個禮拜有七天。', 6),
#  ('法律_06554201_由立法機關制定，有強制效力的行為規範。', 6),
#  ('視為_04165701_比喻把前述對象認定為後述的一類。', 6),
#  ('項_07014202_計算事物分類的單位。', 6),
#  ('部份_04081702_表整體中的特定個體。', 6),
#  ('類_05196002_計算在特定範圍中具有共同特徵的小範圍的單位。', 6),
#  ('板面__', 6),
#  ('交換文__', 6),
#  ('３２__', 6),
#  ('上述_06745701_文章或談話中所敘述過的內容。', 6),
#  ('４１__', 6),
#  ('４３__', 6),
#  ('宣傳__', 6),
#  ('說明_06002002_以文字媒介明確提供後述訊息。', 6),
#  ('六_04082102_序數。順序排在第六。', 6),
#  ('得_05148206_表前述對象具有進行後述事件的條件。', 6),
#  ('申訴__', 6),
#  ('受理__', 6),
#  ('均_05124303_表全部。', 6),
#  ('以下_06521505_在參考點之後的文本順序。', 6),
#  ('判斷__', 6),
#  ('可能_06745903_特定事件實現的可能性。', 6),
#  ('字數__', 6),
#  ('改善__', 6),
#  ('登入__', 6),
#  ('死_05035201_形容沒有生命的。', 6),
#  ('又_04000902_表接連發生事件中的後述發生事件。', 6),
#  ('改正__', 6),
#  ('／／ｔｉｎｙｕｒｌ__', 6),
#  ('依_04018508_引介相同的後述事件情況。', 6),
#  ('４０__', 6),
#  ('讓_04010502_導致後述對象涉入後述事件。', 6),
#  ('第一__', 6),
#  ('真的_05052201_表結果與預期一樣。', 6),
#  ('推ｑａｚｅｄｃ__', 6),
#  ('幸福__', 6),
#  ('Ｌｅｅｈｅａｖｅｎ__', 6),
#  ('啦_04020703_表對前述評語內容具緩和作用的語氣。', 6),
#  ('ｎｉｃｋｙ５１__', 6),
#  ('分享__', 6),
#  ('水_05233801_無色無味的透明液體，是生物生存的必要元素之一。', 6),
#  ('一起_04162502_表不同的主體在同一空間或進行同一事件。', 6),
#  ('志工__', 6),
#  ('輸血__', 6),
#  ('請問_05074101_客氣地提出問題。', 5),
#  ('想_05047204_在心中對特定事件提出推測性的論斷。', 5),
#  ('使用_06722403_使用後述材料製成前述物品。', 5),
#  ('噴_06538602_讓煙從嘴裡出來。', 5),
#  ('跟_03015305_連接並列的詞組，表做連接的事件同時成立。', 5),
#  ('附近_06556801_與參考對象距離近的範圍。', 5),
#  ('站_07015603_架設在網際網路上以HTTP傳輸交換資訊的一個固定網路結點。', 5),
#  ('信_08002601_給特定對象的書面訊息。', 5),
#  ('以前_03050502_在時間參考點之前的時段。', 5),
#  ('家_06708303_一家人居住的建築物及建築物所在的位置。', 5),
#  ('們_06613501_用在指人的名詞之後，表示複數。', 5),
#  ('皆_04034401_表全部。', 5),
#  ('詳細_06546701_形容做事周密，不遺漏小細節。', 5),
#  ('食物_06526101_可供食用的對象的通稱。', 5),
#  ('６５__', 5),
#  ('名稱_06628201_人所取的用來代表特定種類的事物的指稱。', 5),
#  ('店面__', 5),
#  ('一些_05052701_表不確定的小數量。', 5),
#  ('還_05002707_表前述對象符合讓步後的條件。', 5),
#  ('則_06778701_表後述命題和前文相對，具有轉折的語氣。', 5),
#  ('韓_07105601_姓。', 5),
#  ('洗_05235207_比喻在看板上發表大量的文章或文字，以佔據版面。', 5),
#  ('違者__', 5),
#  ('小時_06556701_一個平均太陽日的二十四分之一。', 5),
#  ('媒體_06637101_對大眾傳遞消息、知識的工具，包括報紙、廣播、電視。', 5),
#  ('作者_06765101_創作文學藝術作品的人。', 5),
#  ('新_05237901_形容特定對象剛產生不久。', 5),
#  ('高市_05092101_位於臺灣南部，為臺灣第二個直轄市。', 5),
#  ('表示_04160103_顯示事物所表達的推論意義。', 5),
#  ('目標_06612102_比喻特定對象所要達到的標準。', 5),
#  ('食品__', 5),
#  ('來信_05178602_寄至參考點的信。', 5),
#  ('日期__', 5),
#  ('處分__', 5),
#  ('好_04157715_評價前述命題達到標準。', 5),
#  ('飲料_13596901_經加工後供飲用的液體。', 5),
#  ('版友__', 5),
#  ('某_03029801_代指沒有指名的後述對象。', 5),
#  ('好_04157704_表示同意或允許。', 5),
#  ('某些_03029901_代稱不指名的複數對象。', 5),
#  ('中_04004603_在前述對象所包含的空間範圍。', 5),
#  ('亂_06702811_以言語或行為打擾或戲弄特定對象。', 5),
#  ('貼_06650008_比喻把文字、圖片或連結公佈在網路上。', 5),
#  ('板務__', 5),
#  ('而已_03011201_說話人用來限定所陳述之事件的範圍或程度，表示僅此而已。', 5),
#  ('自己_05076901_代指主事者。', 5),
#  ('四_05076701_數目字。整數，為三加一的和。', 5),
#  ('２９__', 5),
#  ('發言__', 5),
#  ('首犯__', 5),
#  ('自己_05076903_緊鄰的前述對象，強調事件不牽涉其他的對象。', 5),
#  ('知道_05233901_具有特定訊息或知識。', 5),
#  ('生活_06743601_日常活動的情況。', 5),
#  ('１２__', 5),
#  ('回文__', 5),
#  ('此_04153503_說話時間相關的事件點。', 5),
#  ('為_05010302_引介事件原因。', 5),
#  ('情節__', 5),
#  ('七_04081501_數目字。整數，為六加一的和。', 5),
#  ('租賃__', 5),
#  ('置_07037201_將物品安置於特定位置上。', 5),
#  ('為_04012002_認知者對前述事物的判斷是後述對象。', 5),
#  ('販賣__', 5),
#  ('２４__', 5),
#  ('２５__', 5),
#  ('關於_03016101_引介涉及的事物。', 5),
#  ('玩樂__', 5),
#  ('情形_06585301_前述事件呈現出來的狀態。', 5),
#  ('商業_05222601_以營利為目的的事業。', 5),
#  ('廣告_06662503_與廣告相關的工業，包括週邊相關的所有活動。', 5),
#  ('閱讀__', 5),
#  ('刪文__', 5),
#  ('刻意_06713901_表帶有明確意圖做事。', 5),
#  ('理由_06579601_事情的原因。', 5),
#  ('的_09002801_表以前述動作的狀態。', 5),
#  ('以上_06576005_順序在參考點之前的文本。', 5),
#  ('分類__', 5),
#  ('處份__', 5),
#  ('達_06706704_數值與後述標準相同或更高。', 5),
#  ('６０__', 5),
#  ('去_06559201_向特定地點移動。', 5),
#  ('確定__', 5),
#  ('修正__', 5),
#  ('查詢__', 5),
#  ('所_04084001_表示以賓語為中心語的關係子句。', 5),
#  ('３７__', 5),
#  ('智障_14603503_形容人能力不足。', 5),
#  ('又_04000903_表事件重複發生。', 5),
#  ('３８__', 5),
#  ('可_08058501_和後述對象的心意相符。', 5),
#  ('４７__', 5),
#  ('記得_06661701_將特定事物放在記憶中。', 5),
#  ('愛_06708115_經常發生後述行為或變化。', 5),
#  ('藥_06653702_令人上癮並危害身體健康的物質。', 5),
#  ('跑出來__', 5),
#  ('詞彙__', 5),
#  ('戰_06651608_比喻在持續的競爭中以前述對象為手段並做為當次對立競爭勝負標準的一次競爭。', 5),
#  ('０９／１０２２__', 5),
#  ('引戰__', 5),
#  ('為_04012004_經過特定過程形成後述結果。', 5),
#  ('暖_07048401_形容溫度微高或感覺溫度微高的。', 5),
#  ('引_05110104_比喻帶領後述對象進入特定領域。', 5),
#  ('推ＨＡＮＡＸＡＬＩＣＥ__', 5),
#  ('５６__', 5),
#  ('５７__', 5),
#  ('我們_05224801_代指說話者和聽話者雙方。', 5),
#  ('察覺__', 5),
#  ('功成身退__', 5),
#  ('憨粉__', 5),
#  ('肺_06590201_動物呼吸器官之一，主要功能為使帶二氧化碳的血液變成帶氧的血液。', 5),
#  ('也_06774603_表預期會改變的情況維持不變。', 4),
#  ('地方_06722201_具有特定特質所描述的，或以特定地點為參考點的區域範圍。', 4),
#  ('補_06566311_在特定事件應完成的時間之後完成特定事件。', 4),
#  ('照片_06657601_經由攝影器材所拍攝出來的圖片。', 4),
#  ('ｊｐｇｈｔｔｐｓ__', 4),
#  ('發現__', 4),
#  ('沒有_04001905_否定事件的發生。', 4),
#  ('有_04013806_引介不指名的後述對象。', 4),
#  ('得_09003201_表特定動作的程度、結果或特質。', 4),
#  ('一直_06640102_表事件持續不間斷。', 4),
#  ('也_06774606_表轉折。', 4),
#  ('換_06607002_以新的同類對象替代原本的對象。', 4),
#  ('有效_06583202_形容發揮效力的。', 4),
#  ('才_06726003_表強調事件發生的比預期晚。', 4),
#  ('已經_06614001_表後述事件在說話之前發生或完成。', 4),
#  ('那_04020106_表言談中用於標記語氣的轉折。', 4),
#  ('開始__', 4),
#  ('狀況_06771902_人的生理、心理或生活狀態。', 4),
#  ('什麼_05224702_指任何對象。', 4),
#  ('辦_06579802_籌備以進行特定活動。', 4),
#  ('些_04045801_表不確定的小數量。', 4),
#  ('另外_04030504_連接前述事件範圍之外的同類補充說明。', 4),
#  ('過期__', 4),
#  ('直接_06772504_形容表達方式直接的。', 4),
#  ('有關__', 4),
#  ('向_03046603_引介伴隨動作的方向。', 4),
#  ('說_05212406_評價後述對象。', 4),
#  ('的話_05076301_承接前述的假設條件，用來引介下文。', 4),
#  ('蠻_05201801_表接近最高程度，不要把話講滿的委婉說法。', 4),
#  ('簡單_06583301_形容結構單純清楚，容易掌握的。', 4),
#  ('約_06046301_表對一件事做揣測或評估，表示有很大的可能性。', 4),
#  ('會_04143406_表條件符合，就一定實現。', 4),
#  ('豬肉__', 4),
#  ('相同_06581201_形容沒有差別的。', 4),
#  ('和_04156201_連接並列的詞組，表做連接的事件同時成立。', 4),
#  ('時候_06668101_事件發生的時間。', 4),
#  ('從_04014006_引介事件發生的時間起點。', 4),
#  ('到_04000707_引介動作或狀態持續到的時點或時段。', 4),
#  ('韓_04073102_國名，位於亞洲東北部，朝鮮半島南端的國家，以北緯38度線與北韓分界。', 4),
#  ('酸_06536712_以言語輕微諷刺特定對象。', 4),
#  ('只是_04028501_表對後述事物做評估，表示比預期小或少。', 4),
#  ('ｓｉｍｏｎｊｅｎ__', 4),
#  ('新增__', 4),
#  ('警告_05071703_對要禁止的行為所發出的提醒。', 4),
#  ('機電__', 4),
#  ('階段性__', 4),
#  ('新聞文__', 4),
#  ('一_06727306_表後述動作的完整性。', 4),
#  ('點_04043811_計算命題內容的事項單位。', 4),
#  ('捷運局__', 4),
#  ('系統_06751204_控制電腦作業與其周邊資源運用的套裝軟體。', 4),
#  ('；__', 4),
#  ('雖然_06559801_連接不影響後述事實的條件，隱含讓步。', 4),
#  ('第三__', 4),
#  ('確認__', 4),
#  ('２０２０年__', 4),
#  ('惡意__', 4),
#  ('聯絡__', 4),
#  ('試_05123002_在尚未正式進行前，體驗後述對象。', 4),
#  ('特別_06640301_形容不同於一般的。', 4),
#  ('多_03010606_表比預期程度更強。', 4),
#  ('到_04000701_前往或抵達後述地點。', 4),
#  ('工廠_06718901_運用技術將原料製成特定物品的場所。', 4),
#  ('著_04005101_時態標記。表前述動作持續進行。', 4),
#  ('想要_06580001_心中存有完成後述事件的願望。', 4),
#  ('那些_04081601_離說話者或參考點較遠的多個對象。', 4),
#  ('造成_06750601_因前述對象而產生後述結果。', 4),
#  ('ｐｎｇ__', 4),
#  ('讓_04010501_允許事件發生。', 4),
#  ('就_05198310_用於轉折，表與聽話者有共識。', 4),
#  ('算_04114304_計算時包括所述事件。', 4),
#  ('才_06726005_表強調所說的事。', 4),
#  ('編號_05019802_依序所定的號碼。', 4),
#  ('救援__', 4),
#  ('對象_06636701_通指人類一切活動所指的人或事物。', 4),
#  ('性別__', 4),
#  ('動物_05226801_可自行攝取有機物為食物，有神經、感覺、且能運動的生物。', 4),
#  ('怎麼_04007202_表對事件的方式、性質或狀況的間接詢問。', 4),
#  ('４６__', 4),
#  ('網軍_14602401_指特定陣營指派進入網路上製造對自己有利狀況的人。', 4),
#  ('用語__', 4),
#  ('不妥__', 4),
#  ('含_05070802_眼淚留在眼眶但未掉下。', 4),
#  ('超過_06706801_數目或數量大於後述對象。', 4),
#  ('２３__', 4),
#  ('查發文__', 4),
#  ('高雄_06047403_高雄的文化。', 4),
#  ('上_04081317_按前述事物的觀點來陳述。', 4),
#  ('造謠__', 4),
#  ('自由__', 4),
#  ('分鐘_03013002_計算時間的單位，一分鐘為一小時的六十分之一。', 4),
#  ('點數__', 4),
#  ('非_04038002_前述事件與後述事件不相等。', 4),
#  ('１３__', 4),
#  ('員工_06694001_特定機構中所雇用的人員。', 4),
#  ('買賣區__', 4),
#  ('贈品__', 4),
#  ('換_06607005_以接近等值的物品或貨幣取代。', 4),
#  ('註明__', 4),
#  ('且_04000603_表暫時退讓。', 4),
#  ('樂文__', 4),
#  ('至多_05105101_表最高限度，不多於後述數量範圍。', 4),
#  ('受_04011401_引介後述對象為事件的施事者。', 4),
#  ('攻擊__', 4),
#  ('影響__', 4),
#  ('權利_06765801_自然人或法人依據法律規定、約定俗成或天賦可行使的權力或應享有的利益。', 4),
#  ('原_03052802_形容最初、起初。', 4),
#  ('所有_03040701_一切、全部。', 4),
#  ('附上__', 4),
#  ('期間_06770701_一段時間。', 4),
#  ('提出_06773706_將文件列入正式紀錄，進入法律程序。', 4),
#  ('合併__', 4),
#  ('重複_06598301_相同的事件再次發生。', 4),
#  ('３６５０__', 4),
#  ('累犯__', 4),
#  ('主帳號__', 4),
#  ('相似__', 4),
#  ('為_05010201_引介事件施事者。', 4),
#  ('回覆__', 4),
#  ('詢問__', 4),
#  ('他們_05196801_代指說話者和聽話者以外的複數人。', 4),
#  ('起訴__', 4),
#  ('此_04153502_前述事物的代稱。', 4),
#  ('個資__', 4),
#  ('明確_06765201_形容清楚沒有歧義的。', 4),
#  ('支持_06665103_以主觀意志維持後述狀態。', 4),
#  ('２６__', 4),
#  ('轉_05228822_比喻電話由總機接到分機。', 4),
#  ('問題_06560402_需要被討論解決的困難。', 4),
#  ('發覺_05050902_主動察覺後述對象的特性。', 4),
#  ('０９／０６０７__', 4),
#  ('４８__', 4),
#  ('歲_06559405_計算年齡的單位。', 4),
#  ('幫忙__', 4),
#  ('屬有__', 4),
#  ('又_04000905_言談中用來表主題的轉折。', 4),
#  ('次_05048204_事件或時間順序在參考點之後。', 4),
#  ('一定_05052501_表對推論的肯定，沒有例外。', 4),
#  ('腦粉__', 4),
#  ('丁允恭__', 4),
#  ('爆_07069608_比喻將他人不想被人知道的事說出。', 4),
#  ('美_06634804_形容比喻過於理想化而與現實脫節的。', 4),
#  ('豬_06570501_哺乳類動物，偶蹄，腿短，身體肥胖，為主要用於食用的家畜。', 4),
#  ('０９／１００９__', 4),
#  ('推ｂａｎａｎａ２４６__', 4),
#  ('噁心_14600701_形容想吐的感覺。', 4),
#  ('ｅｇｇｏｍｅｇａ__', 4),
#  ('白_05023503_形容同類事物中顏色比較淺的。', 4),
#  ('還_05002701_表動作或情況持續不變。', 4),
#  ('不可_04038601_表不應該。', 4),
#  ('生物_06633501_自然界中所有具有生命並有生長繁殖能力的物體。', 4),
#  ('０９__', 4),
#  ('升級_06598202_功能或品質由較低升到較高。', 4),
#  ('依_04018507_引介遵循固定的程序或規劃。', 4),
#  ('暫不_03054801_表暫時不。', 4),
#  ('０９／１１１４__', 4),
#  ('檢討__', 4),
#  ('０９／１１１３__', 4),
#  ('領_07103406_經過特定程序向特定對象取得主事者擁有或應該擁有的金錢或物品。', 4),
#  ('到_04000709_引介動作或狀態達到的階段或程度。', 4),
#  ('ｃａｒｅ__', 4),
#  ('人_05231104_每個人。', 4),
#  ('繼續__', 4),
#  ('０７__', 4),
#  ('戰_06651602_在戰爭的過程中，敵對軍隊間的一次武力衝突。', 4),
#  ('思考__', 4),
#  ('搞__', 4),
#  ('噓ｒｅｂｕｉｌｄＭｏｄｅｌ__', 4),
#  ('給予_03015201_前述對象將特定事物所有權移轉到後述對象。', 4),
#  ('節錄__', 4),
#  ('跟_03015302_引介比較的對象。', 4),
#  ('像_03046701_與前述對象有共同點的是後述對象。', 4),
#  ('垃圾_06607301_被丟棄的或被認為沒有價值的物品。', 4),
#  ('推ａｍｇｎ９９７__', 4),
#  ('推ｓｉｇｎｏｒｒ__', 4),
#  ('０９／１６１９__', 4),
#  ('５５__', 4),
#  ('冷氣__', 4),
#  ('把_04011703_引介認知評價的對象。', 4),
#  ('南部_06652901_空間範圍內南邊的區域。', 4),
#  ('潑_09167901_用力將液體向外灑。', 4),
#  ('民宅__', 4),
#  ('月餅__', 4),
#  ('２８__', 4),
#  ('第１５__', 4),
#  ('朝聖__', 4),
#  ('越_03053504_表程度隨著條件的發展而變化。', 4),
#  ('崩潰__', 4),
#  ('蘇光頭__', 4),
#  ('卵_07039701_雌性動物的生殖細胞。', 4),
#  ('三_05224301_數目字，整數，為二加一的和。', 4),
#  ('報名__', 4),
#  ('感謝__', 3),
#  ('誰_04090701_代指詢問一個或多數的人。', 3),
#  ('呢_04021001_表對內容的疑問，隱含說話者已有所認定。', 3),
#  ('氣球__', 3),
#  ('歌_06743302_有旋律和詞、可供人歌唱的音樂作品。', 3),
#  ('小朋友_06612501_小孩的總稱，通常指12歲以下。', 3),
#  ('什麼_05224703_否定所描述對象或降低其價值。', 3),
#  ('溫馨__', 3),
#  ('非常_05216701_表超過平常的程度。', 3),
#  ('鄉民_14602501_住在鄉下的人。', 3),
#  ('香水__', 3),
#  ('價值_06638603_比喻事物的用途或正面作用。', 3),
#  ('索取__', 3),
#  ('味道_14357702_鼻子聞特定物質所得到的感覺，物體散發出的氣味。', 3),
#  ('ｃｏｍ／__', 3),
#  ('期限__', 3),
#  ('樹_05235601_木本植物類的通稱，多年生植物，主要由樹幹及樹葉組成。', 3),
#  ('蘋果__', 3),
#  ('大概_03008701_表對特定事件做揣測、評估，表示有很大的可能性。', 3),
#  ('到_04000703_數值與後述標準相同或更高。', 3),
#  ('找_06558903_和後述對象連繫以進行特定活動。', 3),
#  ('紀錄_05009504_在一定的時間和範圍限制下所創造的最佳成績。', 3),
#  ('個_06533603_形容單獨一人。', 3),
#  ('網購__', 3),
#  ('配合_06666304_形容兩個特定對象間的搭配很協調。', 3),
#  ('心得__', 3),
#  ('像是__', 3),
#  ('常_07113004_表次數很多。', 3),
#  ('根本_04038103_表完全。', 3),
#  ('左右__', 3),
#  ('變成_06665801_前述對象因顯著特性的取代而成為的是後述對象。', 3),
#  ('１４０__', 3),
#  ('元_07105901_計算貨幣的基本單位。', 3),
#  ('開始_04085904_表示事件時間範圍的開始參考點。', 3),
#  ('雙主菜__', 3),
#  ('咖哩飯__', 3),
#  ('炸_08046801_引爆彈藥破壞或攻擊特定目標物。', 3),
#  ('給_04011501_前述對象將特定事物所有權移轉到後述對象。', 3),
#  ('還_05002704_表超出預料。', 3),
#  ('湯汁__', 3),
#  ('不錯_06636301_形容正確的。', 3),
#  ('小_05227107_形容年紀比特定對象小。', 3),
#  ('發_05193405_形容意外得到大量財物。', 3),
#  ('財_07042501_有價值的貨幣或資產。', 3),
#  ('網路_06667803_比喻內部組織結構像網一樣互相連結的組織系統。', 3),
#  ('而_04000806_表言談中用來表主題的轉折。', 3),
#  ('操作__', 3),
#  ('事_06533001_與人類活動相關的一切對象。', 3),
#  ('不要_05076502_表勸阻。', 3),
#  ('利用__', 3),
#  ('退_05131810_拒絕。', 3),
#  ('網址__', 3),
#  ('方便_04151802_使特定事件的目的容易達到。', 3),
#  ('網友__', 3),
#  ('／／ｗｗｗ__', 3),
#  ('ｃｏｍ__', 3),
#  ('車_06665201_在陸地上以輪子行駛的運輸工具。', 3),
#  ('上線__', 3),
#  ('來源_06552602_比喻開創或造成前述對象的特定對象。', 3),
#  ('中央社__', 3),
#  ('媒體_06637102_從事媒體工作的人或團體。', 3),
#  ('詞_06746503_用來表示特定事物或概念的詞或片語。', 3),
#  ('更新__', 3),
#  ('記者_06665001_負責採訪新聞與報導的人。', 3),
#  ('明天__', 3),
#  ('至_03057502_引介到達特定地點或時間。', 3),
#  ('工程_06694301_有一定計畫的建設工作。', 3),
#  ('測試__', 3),
#  ('作業__', 3),
#  ('方_05012702_表因前述事情而導致後述事件。', 3),
#  ('代表_06746704_在同類對象中特性最顯著的特定對象。', 3),
#  ('後續_05046701_形容接續前述事件並與前述事件相關的。', 3),
#  ('工作_06771802_擔任的任務或使命。', 3),
#  ('全_05100805_事物的全體。', 3),
#  ('城市_09291401_人口聚集的區域，通常為四周區域的政治、經濟、文化與交通中心。', 3),
#  ('則_05145502_計算文字或圖片的單位。', 3),
#  ('自刪__', 3),
#  ('注意__', 3),
#  ('每_03028202_表只要。', 3),
#  ('楠梓__', 3),
#  ('烘碗機__', 3),
#  ('四_05076702_序數。順序排在第四。', 3),
#  ('就_05198303_表後述事件緊接著前述事件發生。', 3),
#  ('ｐｔｔ__', 3),
#  ('收取__', 3),
#  ('眼鏡__', 3),
#  ('拜託_04105401_提出要求，請他人幫忙。', 3),
#  ('洽中__', 3),
#  ('健身__', 3),
#  ('杯_04082502_計算杯裝物的單位。', 3),
#  ('皮革__', 3),
#  ('所以_06751401_連接因上述原因而得到的後述結果或結論。', 3),
#  ('們_06613502_用在指人以外的名詞之後，表示複數。', 3),
#  ('ＩＤ__', 3),
#  ('工作_06771803_在社會中所擔任的職務，通常為其身份認定的依據。', 3),
#  ('至於_04018601_引介不同的觀點，作為新話題。', 3),
#  ('ＰＯ__', 3),
#  ('情況_06640001_前述事件呈現出來的狀態。', 3),
#  ('平衡_06689407_比喻使形容比喻兩個以上互相對立的特定對象之間保持穩定的發展。', 3),
#  ('一下__', 3),
#  ('也_06774607_表讓步的語氣。', 3),
#  ('柯韓粉__', 3),
#  ('貼文__', 3),
#  ('何_04080801_表未確定對象的詢問。', 3),
#  ('結果_05051803_事物經發展變化後的最後狀況。', 3),
#  ('而_04000805_連接句子或動詞組，表轉折關係。', 3),
#  ('不_04002001_表否定，用在動詞、狀態形容詞與副詞前。', 3),
#  ('是_09250002_表回應對方的話。', 3),
#  ('網路_06667801_架設在網際網路上以HTTP傳輸交換資訊的所有網站的總稱。', 3),
#  ('標籤__', 3),
#  ('一_06727303_表另外。', 3),
#  ('把_04011701_引介處置的對象。', 3),
#  ('當年__', 3),
#  ('實在_04038807_表對客觀情況的真實性給予評價。', 3),
#  ('難_06558501_形容特定事件無法輕易達成。', 3),
#  ('物資__', 3),
#  ('告知__', 3),
#  ('隻_05100201_計算動物數量的單位。', 3),
#  ('醫院_06638101_提供病患診治、醫療照顧及住院的醫療機構。', 3),
#  ('正常__', 3),
#  ('今_07026602_說話者所在的時間參考點的那一天。', 3),
#  ('平穩__', 3),
#  ('在_04015707_等同。', 3),
#  ('緊急__', 3),
#  ('說明_06002001_以口語媒介明確提供後述訊息。', 3),
#  ('１０／３１__', 3),
#  ('１１／０１２３__', 3),
#  ('稱呼_04120101_叫特定對象的名字是後述對象。', 3),
#  ('她_05124901_代指自己和對方以外的單數女性第三者，指人。', 3),
#  ('稱呼_04120102_引述客氣的稱謂是後述對象。', 3),
#  ('覺得_05209203_引述或陳述前述對象的認知或感受。', 3),
#  ('侮辱__', 3),
#  ('行_06775711_形容表示同意或允許。', 3),
#  ('柯文哲__', 3),
#  ('在_04015706_引介後述事件的範圍。', 3),
#  ('有_04013805_達到後述程度。', 3),
#  ('提到_06552301_陳述時指涉到後述事件。', 3),
#  ('疏失__', 3),
#  ('報導_06748202_報導的內容。', 3),
#  ('公告__', 3),
#  ('以_04014103_引介達成事件的條件。', 3),
#  ('太多_05122402_形容前述特質的程度高。', 3),
#  ('吧_04020903_表推測的語氣。', 3),
#  ('最近_07025701_說話者表達與說話時前後相差不久的時間。', 3),
#  ('以下_06521504_等於或低於前述數目。', 3),
#  ('鳳山__', 3),
#  ('規則_06576201_應該遵守的規定。', 3),
#  ('台灣_04164502_位於臺灣島的國家，建立於西元1912年的民主共和國，轄區包含臺灣、澎湖、金門、馬祖。', 3),
#  ('娛樂_14224701_使人感到愉快的活動。', 3),
#  ('事件_06611301_發生在特定時間地點的事，具有特定影響力。', 3),
#  ('無關__', 3),
#  ('原_03052801_表沒有經過改變的，或者改變之前的。', 3),
#  ('中華民國_06606501_位於臺灣島的國家，建立於西元1912年的民主共和國，轄區包含臺灣、澎湖、金門、馬祖。', 3),
#  ('信件__', 3),
#  ('１／２１__', 3),
#  ('１６__', 3),
#  ('手動置底__', 3),
#  ('特殊__', 3),
#  ('需求_06638701_特定對象所仰賴的其他對象。', 3),
#  ('給_04011503_使後述人物參與。', 3),
#  ('票據__', 3),
#  ('票根__', 3),
#  ('２／２１__', 3),
#  ('簽名檔__', 3),
#  ('合購__', 3),
#  ('以_04014111_連接前述事件的目的。', 3),
#  ('開放_06664204_形容沒有隔間的。', 3),
#  ('底_04086111_備份的紀錄。', 3),
#  ('形式__', 3),
#  ('徵_06755803_公開尋求特定作品。', 3),
#  ('例如_03026701_引介例子。', 3),
#  ('間隔__', 3),
#  ('１／１１__', 3),
#  ('等_04001106_計算事物種類的單位。', 3),
#  ('限定__', 3),
#  ('玩_05238101_進行後述遊戲，通常從過程中得到樂趣。', 3),
#  ('課程_06749501_在特定學校系統中依照學術領域區分的學生修習課程的單位。', 3),
#  ('要求__', 3),
#  ('開放_06664205_形容容易接受新事物的。', 3),
#  ('註_06627701_用來補充說明或解釋本文的文字。', 3),
#  ('公告文__', 3),
#  ('違法__', 3),
#  ('臨時__', 3),
#  ('任意__', 3),
#  ('地區_06750701_具有特定特質所描述的，或以特定地點為參考點的範圍。', 3),
#  ('申請__', 3),
#  ('許可__', 3),
#  ('得以_04035201_表藉由特定方式達成。', 3),
#  ('其_06533301_代指前述提及的特定對象所擁有的。', 3),
#  ('提出_06773702_發表後述想法或提案。', 3),
#  ('符合_06554001_與所訂的要求、條件相符。', 3),
#  ...]

# %% [markdown]
# ### 5. 台北板詞頻表、詞類頻表、詞義頻表

# %% [markdown]
# #### 5.1 台北板詞頻表

# %%
# sorting word frequency tables
tp_tables = freq_tables(tp_tagged_sense)
tp_tables_word = list(tp_tables[0].items())
sorted(tp_tables_word, reverse=True, key=lambda x: x[1])

# %% [markdown]
# #### 5.2 台北板詞類頻表

# %%
# sorting pos frequency tables
tp_tables_pos = list(tp_tables[1].items())
sorted(tp_tables_pos, reverse=True, key=lambda x: x[1])

# %% [markdown]
# #### 5.3 台北板詞義頻表

# %%
# sorting sense frequency tables
tp_tables_sense = list(tp_tables[2].items())
sorted(tp_tables_sense, reverse=True, key=lambda x: x[1])
